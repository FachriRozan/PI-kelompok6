# %%
import os
import glob
import heapq
import nltk
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import tokenized

# Create stopword remover object
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

# Create a stemming object
stemmer_factory = StemmerFactory()
stemmer = stemmer_factory.create_stemmer()

# Open the file for reading
with open('tokenized_documents.txt', 'r', encoding='utf-8') as f:
    # Read the contents of the file and combine tokens back into text
    documents = [' '.join(line.strip().split()) for line in f]

# Tokenisasi, penghapusan stopwords, dan stemming pada query
query = input("Masukkan kata yang ingin dicari: ")
query = stopword.remove(query)  # Menghapus stopwords dari query
query_tokens = nltk.word_tokenize(query)  # Tokenisasi query
query_tokens = [stemmer.stem(word) for word in query_tokens]  # Melakukan stemming pada query

# Create a TF-IDF vectorizer
vectorizer = TfidfVectorizer(use_idf=True, smooth_idf=True)

# Calculate the TF-IDF vectors for the documents
tfidf_matrix = vectorizer.fit_transform(documents)
features = vectorizer.get_feature_names_out()

# Transform the query into a TF-IDF vector
query_vector = vectorizer.transform([' '.join(query_tokens)])

# Calculate the cosine similarity scores between the query vector and the document vectors
cosine_scores = cosine_similarity(query_vector, tfidf_matrix)

# Membuat daftar dokumen yang relevan dengan kata-kata dalam query
relevant_documents = []
for i, document_tokens in enumerate(documents):
    if any(word in document_tokens for word in query_tokens):
        relevant_documents.append(i)

# Function to calculate Jaccard Similarity
def jaccard_similarity(set1, set2):
    set1 = set(set1)
    set2 = set(set2)
    intersection = len(set1.intersection(set2))
    union = len(set1) + len(set2) - intersection
    return intersection / union if union != 0 else 0

# Calculate Jaccard Similarity scores for each document
jaccard_scores = [jaccard_similarity(query_tokens, nltk.word_tokenize(document)) for document in documents]

# Get the top-ranked documents based on Jaccard Similarity
jaccard_indices = heapq.nlargest(len(relevant_documents), relevant_documents, key=lambda i: jaccard_scores[i])

# Get the document names
document_names = [os.path.basename(file) for file in tokenized.files]

cosine_indices = heapq.nlargest(len(relevant_documents), relevant_documents, key=lambda i: cosine_scores[0][i])

# Print the ranking, document name, score, and word positions in the document
print("Dokumen teratas berdasarkan cosine similarity:")
for rank, i in enumerate(cosine_indices, start=1):
    print(f"Rank: {rank}")
    print(f"Nama Dokumen: {document_names[i]}")
    print(f"Skor Cosine Similarity: {cosine_scores[0][i]}")
    positions = [idx for idx, word in enumerate(documents[i].split()) if word in query_tokens]
    print(f"Posisi Index untuk Kata dalam Query: {positions}")
    print()

print("Dokumen teratas berdasarkan Jaccard Similarity:")
for rank, i in enumerate(jaccard_indices, start=1):
    print(f"Rank: {rank}")
    print(f"Nama Dokumen: {document_names[i]}")
    print(f"Skor Jaccard Similarity: {jaccard_scores[i]}")
    positions = [idx for idx, word in enumerate(documents[i].split()) if word in query_tokens]
    print(f"Posisi Index untuk Kata dalam Query: {positions}")
    print()

# Menyimpan nama dokumen ke dalam file
with open('document_names.txt', 'w', encoding='utf-8') as txt_file:
    txt_file.write('\n'.join(document_names))

print("Nama dokumen telah disimpan dalam file: document_names.txt")
# Out:
# Dokumen teratas berdasarkan cosine similarity:
# Rank: 1
# Nama Dokumen: Muhammad.txt
# Skor Cosine Similarity: 0.5335502064450063
# Posisi Index untuk Kata dalam Query: [6, 8, 60, 62, 68, 70, 120, 135, 152, 168, 176, 214, 227, 259, 269, 300, 316, 330, 356, 381, 388, 399, 400, 434, 447, 521, 530, 547, 549, 620, 635, 747, 749, 751, 759, 767, 773, 808, 812, 836, 857, 863, 897, 907, 918, 932, 978, 1008, 1072, 1080, 1090, 1099, 1103, 1142, 1162, 1164, 1185, 1214, 1285, 1288, 1343, 1367, 1370, 1385, 1425, 1465, 1489, 1514, 1546, 1602, 1669, 1684, 1717, 1744, 1749, 1771, 1806, 1827, 1861, 1881, 1929, 1972, 1992, 2024, 2062, 2077, 2097, 2110, 2140, 2174, 2222, 2239, 2275, 2314, 2335, 2361, 2365, 2381, 2398, 2428, 2440, 2450, 2454, 2459, 2480, 2501, 2514, 2549, 2574, 2591, 2699, 2715, 2928, 2936, 2953, 2972, 2975, 3044, 3048, 3063, 3126, 3139, 3162, 3183, 3226, 3243, 3312, 3322, 3329, 3412, 3427, 3476, 3480, 3490, 3509, 3525, 3548, 3554, 3563, 3585, 3610, 3623, 3659, 3695, 3698, 3709, 3735, 3746, 3770, 3791, 3857, 3877, 3883, 3898, 3911, 3929, 3934, 3958, 3964, 3982, 3993, 3998, 4029, 4050, 4122, 4158, 4192, 4260, 4285, 4305, 4308, 4319, 4339, 4380, 4390, 4431, 4451, 4476, 4527, 4581, 4598, 4640, 4691, 4699, 4712, 4740, 4756, 4775, 4794, 4799, 4839, 4849, 4868, 4870, 4877, 4911, 4918, 4941, 4971, 4975, 5000, 5014, 5034]
#
# Rank: 2
# Nama Dokumen: Ali_bin_Abi_Thalib.txt
# Skor Cosine Similarity: 0.23353467504529704
# Posisi Index untuk Kata dalam Query: [67, 72, 79, 101, 115, 122, 156, 242, 257, 287, 355, 367, 383, 392, 399, 418, 438, 444, 449, 476, 496, 510, 544, 550, 555, 595, 643, 658, 684, 711, 801, 873, 879, 898, 913, 951, 1010, 1029, 1032, 1049, 1246, 1273, 1554, 1592, 1674, 1809, 1846, 1861, 1873, 1969, 1993, 2020]
#
# Rank: 3
# Nama Dokumen: Penutup_Para_Nabi.txt
# Skor Cosine Similarity: 0.216272220963645
# Posisi Index untuk Kata dalam Query: [30, 37, 47, 95, 119]
#
# Rank: 4
# Nama Dokumen: Muhammad_bin_Abdul_Wahhab.txt
# Skor Cosine Similarity: 0.19802409755423545
# Posisi Index untuk Kata dalam Query: [6, 11, 78, 327, 387, 395, 405, 413, 476, 482, 518, 545, 552, 628, 672, 689, 714, 738, 772, 796, 852, 875, 892, 952, 977, 1016, 1028, 1038, 1065, 1096, 1120, 1141, 1209, 1245, 1250, 1358, 1408, 1435, 1445, 1513, 1585, 1598, 1638, 1665, 1685, 1703, 1715, 1724, 1789, 1825, 1837, 1843, 1860, 1871, 1889, 1942, 1959, 1964, 1981, 2091, 2093, 2108, 2113, 2118, 2283, 2653, 2685, 2759, 2783, 2806, 2837, 2841, 2952, 3059, 3092, 3153, 3189, 3227, 3245, 3262, 3275, 3291, 3333, 3381, 3388, 3400, 3583, 3870, 3875, 3885, 3992, 4247, 4405, 4428, 4720, 4783, 4825, 4849, 4886, 4933, 4967, 4990, 5160, 5202, 5264, 5281, 5429, 5549, 5624, 5638]
#
# Rank: 5
# Nama Dokumen: Islam.txt
# Skor Cosine Similarity: 0.1880619611835595
# Posisi Index untuk Kata dalam Query: [91, 358, 423, 506, 1059, 1118, 1131, 1535, 1692, 1695, 1701, 1738, 1758, 1773, 1799, 1808, 1828, 1848, 1870, 1875, 1906, 1911, 1919, 1948, 1967, 2042, 2098, 2120, 2139, 2179, 2199, 2204, 2250, 2314, 2416, 2462, 2478, 2557, 2575, 2809, 2847, 2942, 2958, 2961, 3004, 3203, 3210, 3221, 3265, 3283, 3322, 3354, 3427, 3692, 4091, 4143, 4247, 4264, 4329, 4475, 4532]
#
# Rank: 6
# Nama Dokumen: Hijrah.txt
# Skor Cosine Similarity: 0.17645819835871696
# Posisi Index untuk Kata dalam Query: [21, 39, 57, 343, 347, 360, 372, 398, 428, 463, 505, 534, 586, 617, 639, 656, 707]
#
# Rank: 7
# Nama Dokumen: Pertempuran_Jamal.txt
# Skor Cosine Similarity: 0.1672421769459266
# Posisi Index untuk Kata dalam Query: [53, 57, 65, 71, 80, 103, 140, 164, 179, 202, 210, 270, 275, 284, 299, 303, 314, 344, 350, 374, 375, 392, 404, 409, 416, 424, 492, 520, 527, 540, 547, 556, 618, 668, 699, 793, 1023, 1060, 1224, 1551, 1622, 1739, 1960, 1966, 2374]
#
# Rank: 8
# Nama Dokumen: Ekspedisi_Tabuk.txt
# Skor Cosine Similarity: 0.15668697747363733
# Posisi Index untuk Kata dalam Query: [30, 70, 87, 103, 134, 143, 155, 161, 189]
#
# Rank: 9
# Nama Dokumen: Pertempuran_Badar.txt
# Skor Cosine Similarity: 0.1320979960719782
# Posisi Index untuk Kata dalam Query: [109, 130, 196, 241, 287, 302, 313, 397, 404, 460, 504, 521, 528, 546, 555, 696, 804, 841, 861, 912, 928, 968, 978, 1018, 1101, 1201, 1301, 1358, 1452, 1480, 1517, 1543, 1841, 2003, 2096, 2372, 2390, 2428, 2463, 2600, 2617, 2665, 2697, 2712, 2748, 2795, 3182, 3380]
#
# Rank: 10
# Nama Dokumen: Pengepungan_rumah_Utsman.txt
# Skor Cosine Similarity: 0.12593147519630238
# Posisi Index untuk Kata dalam Query: [234, 403, 435, 452, 466, 478, 481, 525, 748, 752, 793, 842, 857, 861, 928, 1041, 1132, 1262, 1276, 1283, 1295, 1394, 1670]
#
# Rank: 11
# Nama Dokumen: Perjanjian_Hudaibiyyah.txt
# Skor Cosine Similarity: 0.12285979722075795
# Posisi Index untuk Kata dalam Query: [147, 162, 253, 268, 284, 298, 469, 470]
#
# Rank: 12
# Nama Dokumen: Surah_Ad-Duha.txt
# Skor Cosine Similarity: 0.12153668912487275
# Posisi Index untuk Kata dalam Query: [58, 104, 128, 158, 251, 265]
#
# Rank: 13
# Nama Dokumen: Pertempuran_Zaturriqa.txt
# Skor Cosine Similarity: 0.11953612664096322
# Posisi Index untuk Kata dalam Query: [53, 134, 149, 161, 165]
#
# Rank: 14
# Nama Dokumen: Abu_al-Hasan_al-Asy_ari.txt
# Skor Cosine Similarity: 0.11670530024477223
# Posisi Index untuk Kata dalam Query: [215, 234, 235, 255, 262, 284, 286, 315]
#
# Rank: 15
# Nama Dokumen: Fikih.txt
# Skor Cosine Similarity: 0.11599526364721016
# Posisi Index untuk Kata dalam Query: [59, 571, 578, 596, 640, 684, 707, 726, 736, 756, 769, 780, 792, 823, 827, 843, 851, 862, 883, 917, 1413]
#
# Rank: 16
# Nama Dokumen: Isra_Mikraj.txt
# Skor Cosine Similarity: 0.11399858821630483
# Posisi Index untuk Kata dalam Query: [20, 25, 46, 63, 117, 160, 197, 243, 894, 904, 926, 964, 971, 1176, 1304, 1315, 1326, 1376, 1462, 1520]
#
# Rank: 17
# Nama Dokumen: Umar_bin_Khattab.txt
# Skor Cosine Similarity: 0.11002497239612691
# Posisi Index untuk Kata dalam Query: [72, 77, 142, 386, 398, 413, 425, 435, 452, 472, 477, 499, 518, 543, 587, 701, 715, 736, 881, 933, 944, 1003, 1016, 1019, 1045, 1073, 1080, 1126, 1138, 1143, 1148, 1166, 1208, 1210, 1229, 1265, 1272, 1297, 1304, 1309, 1765, 2260, 2284, 2646, 2658, 3142, 3828, 4411, 4414, 4917, 5325, 5521, 5529, 5731, 5763, 5805, 5869, 5956, 5960, 5988, 6088, 6179, 6369]
#
# Rank: 18
# Nama Dokumen: Abu_Bakar_ash-Shiddiq.txt
# Skor Cosine Similarity: 0.1073398516907693
# Posisi Index untuk Kata dalam Query: [123, 239, 848, 867, 927, 1001, 1015, 1021, 1023, 1044, 1056, 1379, 1617, 1644, 1774, 1832, 1845, 1900, 1912, 1927, 2027, 2063, 2172, 2183, 2760, 3035, 3182, 3253, 3366, 3470, 3498, 3553, 3575, 3612, 3664, 3798, 3847, 3909, 4007, 4057, 4097, 4189]
#
# Rank: 19
# Nama Dokumen: Bani_Quraizhah.txt
# Skor Cosine Similarity: 0.10335909137031819
# Posisi Index untuk Kata dalam Query: [37, 78, 163, 198, 229, 367, 546, 668, 701, 788, 875, 904, 986, 1018, 1046, 1059, 1075, 1086, 1094]
#
# Rank: 20
# Nama Dokumen: Syiah.txt
# Skor Cosine Similarity: 0.10238109932290745
# Posisi Index untuk Kata dalam Query: [74, 94, 113, 129, 136, 140, 327, 354, 366, 384, 414, 424, 440, 543, 569, 875, 881, 885, 909, 915, 917, 922, 936, 941, 1026, 1082, 1088, 1093, 1451, 2108, 2189]
#
# Rank: 21
# Nama Dokumen: Surah_Muhammad.txt
# Skor Cosine Similarity: 0.09922128140334545
# Posisi Index untuk Kata dalam Query: [7, 10, 19, 27, 43, 48, 70, 80, 96, 157, 946]
#
# Rank: 22
# Nama Dokumen: Surah_Yasin.txt
# Skor Cosine Similarity: 0.09731859755059191
# Posisi Index untuk Kata dalam Query: [110, 173, 212, 219, 238, 273, 282, 642, 759, 761, 772]
#
# Rank: 23
# Nama Dokumen: Pertempuran_Hunain.txt
# Skor Cosine Similarity: 0.09699923284711068
# Posisi Index untuk Kata dalam Query: [22, 79, 100, 111, 152, 234, 280, 483]
#
# Rank: 24
# Nama Dokumen: Surah_Al-Kausar.txt
# Skor Cosine Similarity: 0.09547060465906547
# Posisi Index untuk Kata dalam Query: [99, 165, 193, 202, 219]
#
# Rank: 25
# Nama Dokumen: Ibnu_Khuzaimah.txt
# Skor Cosine Similarity: 0.09508212926792232
# Posisi Index untuk Kata dalam Query: [102, 148, 192, 197, 202, 252]
#
# Rank: 26
# Nama Dokumen: Surah_Asy-Syarh.txt
# Skor Cosine Similarity: 0.09394883853965318
# Posisi Index untuk Kata dalam Query: [87, 118, 132, 146]
#
# Rank: 27
# Nama Dokumen: Kekhalifahan_Rasyidin.txt
# Skor Cosine Similarity: 0.09375213836660189
# Posisi Index untuk Kata dalam Query: [26, 51, 187, 350, 375, 488, 493, 505, 511, 546, 581, 600, 631, 712, 733, 792, 930, 950, 952, 993, 1012, 1060, 1079, 1105, 1110, 1135, 1138, 1357, 1371, 1773, 1785, 1863, 1900, 1952, 2419, 2909, 2956, 3051, 3677, 4125, 4233, 4542, 5652, 6300, 6383, 6434, 6601, 6623, 6704, 6708, 6722, 6937, 7493, 7801, 7857, 8253, 8271, 8450, 8473, 8520, 8573, 8609, 8639, 8700]
#
# Rank: 28
# Nama Dokumen: Khalid_bin_Sa_id.txt
# Skor Cosine Similarity: 0.08805310462314798
# Posisi Index untuk Kata dalam Query: [34, 72]
#
# Rank: 29
# Nama Dokumen: Surah_Yunus.txt
# Skor Cosine Similarity: 0.08780629783630112
# Posisi Index untuk Kata dalam Query: [123, 220, 353, 363, 373, 405, 407, 515]
#
# Rank: 30
# Nama Dokumen: Abdullah_bin_Abdul_Muthalib.txt
# Skor Cosine Similarity: 0.0875268580281842
# Posisi Index untuk Kata dalam Query: [40, 50, 64, 73, 281]
#
# Rank: 31
# Nama Dokumen: Marwan_bin_Muhammad.txt
# Skor Cosine Similarity: 0.0847600748652482
# Posisi Index untuk Kata dalam Query: [8, 12, 26, 58, 221]
#
# Rank: 32
# Nama Dokumen: Rasul.txt
# Skor Cosine Similarity: 0.08354833780926339
# Posisi Index untuk Kata dalam Query: [53, 118, 131, 167, 189, 238, 263]
#
# Rank: 33
# Nama Dokumen: Surah_Al-Ikhlas.txt
# Skor Cosine Similarity: 0.08052963382237961
# Posisi Index untuk Kata dalam Query: [183, 205, 273, 371, 537, 601, 668, 701]
#
# Rank: 34
# Nama Dokumen: Salaf.txt
# Skor Cosine Similarity: 0.07758176710228554
# Posisi Index untuk Kata dalam Query: [237, 262, 304, 307, 310, 314, 320, 742]
#
# Rank: 35
# Nama Dokumen: Hakim_an-Naisaburi.txt
# Skor Cosine Similarity: 0.07662941051702131
# Posisi Index untuk Kata dalam Query: [50, 84, 88, 170]
#
# Rank: 36
# Nama Dokumen: Al-Walid_bin_Yazid.txt
# Skor Cosine Similarity: 0.07203465840723038
# Posisi Index untuk Kata dalam Query: [129, 131, 160, 164, 206, 285, 303]
#
# Rank: 37
# Nama Dokumen: Madinah.txt
# Skor Cosine Similarity: 0.07078413849455693
# Posisi Index untuk Kata dalam Query: [85, 100, 149, 272, 291, 393, 397, 408, 530, 552, 605, 1122]
#
# Rank: 38
# Nama Dokumen: Bani_Taim.txt
# Skor Cosine Similarity: 0.07071280782924691
# Posisi Index untuk Kata dalam Query: [55, 127, 157, 167]
#
# Rank: 39
# Nama Dokumen: Yazid_bin_Walid.txt
# Skor Cosine Similarity: 0.06984226721783254
# Posisi Index untuk Kata dalam Query: [80, 86, 113]
#
# Rank: 40
# Nama Dokumen: Kalender_Hijriah.txt
# Skor Cosine Similarity: 0.06866707100538341
# Posisi Index untuk Kata dalam Query: [86, 371, 460, 525, 530, 546, 767, 834, 871, 903, 916, 931, 952, 985, 990, 1066, 1071]
#
# Rank: 41
# Nama Dokumen: Al-Qur_27an.txt
# Skor Cosine Similarity: 0.06782501126185536
# Posisi Index untuk Kata dalam Query: [90, 113, 150, 167, 199, 345, 766, 775, 849, 1000, 1059, 1091, 1110, 1119, 1290, 1784, 2106, 2183, 2260, 2274, 2636, 2749]
#
# Rank: 42
# Nama Dokumen: Surah_Al-An_27am.txt
# Skor Cosine Similarity: 0.0666085574078694
# Posisi Index untuk Kata dalam Query: [162, 180, 230, 266]
#
# Rank: 43
# Nama Dokumen: Ikrimah_bin_Abu_Jahal.txt
# Skor Cosine Similarity: 0.06535595042775424
# Posisi Index untuk Kata dalam Query: [123, 144, 173, 192, 209, 400, 409, 445, 480, 493, 529, 1076]
#
# Rank: 44
# Nama Dokumen: Sunni.txt
# Skor Cosine Similarity: 0.06431334975119274
# Posisi Index untuk Kata dalam Query: [41, 51, 60, 79, 400, 487, 947, 966, 974, 984, 1309, 1475, 1485, 1497, 1537, 1627, 1699, 1722, 1854, 2036, 2205, 2210, 2230, 2538, 3086, 3274, 3448, 4078, 4087, 4279, 4284, 4305, 4321, 4400, 4424, 5308, 5333]
#
# Rank: 45
# Nama Dokumen: Munafik.txt
# Skor Cosine Similarity: 0.06183465089100756
# Posisi Index untuk Kata dalam Query: [307, 403, 514, 523, 529, 534, 543, 660]
#
# Rank: 46
# Nama Dokumen: Kafir.txt
# Skor Cosine Similarity: 0.061215667080093426
# Posisi Index untuk Kata dalam Query: [30, 53, 74, 100, 128, 346, 384, 408, 984, 1032, 1105]
#
# Rank: 47
# Nama Dokumen: Khalid_bin_Walid.txt
# Skor Cosine Similarity: 0.061036043930679615
# Posisi Index untuk Kata dalam Query: [46, 94, 118, 156, 346, 412, 487, 541, 564, 585, 592, 609, 618, 673, 790, 795, 817, 834, 853, 873, 951, 1015, 1068, 1115, 1259, 1273, 1309, 1318, 1341, 1387, 1403, 1415, 1435, 1444, 1527, 1603, 1609, 1896, 1908, 2192, 2197, 2203, 2206, 3423, 3914, 4887, 6156, 6744, 6794, 6850, 6993, 7035, 7403, 8768, 8851, 9116]
#
# Rank: 48
# Nama Dokumen: Syahadat.txt
# Skor Cosine Similarity: 0.06038732488221998
# Posisi Index untuk Kata dalam Query: [113, 209, 273, 395, 460, 545, 660, 683, 907, 1045, 1047, 1158, 1432]
#
# Rank: 49
# Nama Dokumen: Muhammad_bin_Ismail_al-Bukhari.txt
# Skor Cosine Similarity: 0.06008569023848571
# Posisi Index untuk Kata dalam Query: [6, 11, 132, 227, 261, 585, 608, 618, 903]
#
# Rank: 50
# Nama Dokumen: Pengepungan_Tha_if.txt
# Skor Cosine Similarity: 0.05993143521964548
# Posisi Index untuk Kata dalam Query: [85, 136, 198]
#
# Rank: 51
# Nama Dokumen: Sahabat_Nabi.txt
# Skor Cosine Similarity: 0.05819263132548374
# Posisi Index untuk Kata dalam Query: [63, 77, 95, 118, 150, 199, 291, 444, 513, 556, 734, 767, 890, 1163, 1885, 1889, 2233, 2273, 2280, 2296]
#
# Rank: 52
# Nama Dokumen: Surah_At-Taubah.txt
# Skor Cosine Similarity: 0.05674343275355146
# Posisi Index untuk Kata dalam Query: [108, 850, 993, 1083, 1145, 1204, 1333, 1451]
#
# Rank: 53
# Nama Dokumen: Salat_Jumat.txt
# Skor Cosine Similarity: 0.056262846521066306
# Posisi Index untuk Kata dalam Query: [239, 268, 273, 550, 570, 634, 643, 645, 751, 886, 1006, 1085]
#
# Rank: 54
# Nama Dokumen: Masa_pemerintahan_Ali.txt
# Skor Cosine Similarity: 0.05613685491961014
# Posisi Index untuk Kata dalam Query: [62, 206, 692, 1259, 1298, 1343, 1472, 1495, 1510, 1642, 1759, 1763, 1786, 1827, 1899, 2042, 2073, 2197, 2405]
#
# Rank: 55
# Nama Dokumen: Utsman_bin_Affan.txt
# Skor Cosine Similarity: 0.055757753240918646
# Posisi Index untuk Kata dalam Query: [120, 124, 334, 353, 394, 607, 618, 639, 652, 682, 725, 755, 1601, 1988, 2085, 2092, 2190, 2264, 3077, 3205, 3222, 3406]
#
# Rank: 56
# Nama Dokumen: Khalifah#Daftar_Khalifah.txt
# Skor Cosine Similarity: 0.05484979657182441
# Posisi Index untuk Kata dalam Query: [37, 129, 142, 660, 813, 857, 867, 891, 1515, 1625, 2144, 2840, 2851, 2967, 3802, 3819, 3828, 3883, 3925, 3953, 4002, 4020, 4032, 4285, 4539, 4552, 4687, 4724, 4876, 4909, 4924, 4941, 5342]
#
# Rank: 57
# Nama Dokumen: Suku_Quraisy.txt
# Skor Cosine Similarity: 0.05389292753385119
# Posisi Index untuk Kata dalam Query: [86, 884, 891, 913, 921, 938, 959, 970, 1055, 1340, 1430, 1467, 1476, 1479, 1610]
#
# Rank: 58
# Nama Dokumen: Idris.txt
# Skor Cosine Similarity: 0.053023237954844114
# Posisi Index untuk Kata dalam Query: [99, 433, 446, 807, 813, 841, 845, 856, 868, 887, 1200]
#
# Rank: 59
# Nama Dokumen: Surah_Al-Baqarah.txt
# Skor Cosine Similarity: 0.051624980339480014
# Posisi Index untuk Kata dalam Query: [155, 207, 486, 730, 954, 965, 988, 1213]
#
# Rank: 60
# Nama Dokumen: Surah_Al-Fath.txt
# Skor Cosine Similarity: 0.051424806821621136
# Posisi Index untuk Kata dalam Query: [55, 58, 88, 94, 867, 986]
#
# Rank: 61
# Nama Dokumen: Syirik.txt
# Skor Cosine Similarity: 0.04833515309487261
# Posisi Index untuk Kata dalam Query: [424, 1381, 1389, 1415, 1449, 1507, 1577, 1622, 1657, 1682, 1701, 1711]
#
# Rank: 62
# Nama Dokumen: Salat.txt
# Skor Cosine Similarity: 0.04748495736534609
# Posisi Index untuk Kata dalam Query: [76, 113, 632, 654, 677, 727, 763, 771, 921, 929, 957, 969, 1099, 1121, 1290, 1620, 1624, 2076, 2311, 2327, 2428, 3195, 3294]
#
# Rank: 63
# Nama Dokumen: Rukun_Islam.txt
# Skor Cosine Similarity: 0.0460707038540752
# Posisi Index untuk Kata dalam Query: [233, 591, 601, 605, 609, 737, 1551]
#
# Rank: 64
# Nama Dokumen: Hijrah_ke_Abisinia.txt
# Skor Cosine Similarity: 0.04556050005236749
# Posisi Index untuk Kata dalam Query: [47, 130, 153]
#
# Rank: 65
# Nama Dokumen: Sufisme.txt
# Skor Cosine Similarity: 0.04546981876125428
# Posisi Index untuk Kata dalam Query: [322, 454, 483, 567, 599, 610, 752, 766, 830, 1420, 1512, 2194, 2615, 2646, 2665]
#
# Rank: 66
# Nama Dokumen: Surah_An-N_C4_81s.txt
# Skor Cosine Similarity: 0.04427182835187204
# Posisi Index untuk Kata dalam Query: [186, 302, 314, 359]
#
# Rank: 67
# Nama Dokumen: Ibnu_Hazm.txt
# Skor Cosine Similarity: 0.04332910435528903
# Posisi Index untuk Kata dalam Query: [79, 172, 344]
#
# Rank: 68
# Nama Dokumen: Ka_27bah.txt
# Skor Cosine Similarity: 0.04267914238614228
# Posisi Index untuk Kata dalam Query: [142, 515, 555, 568, 657, 764, 830, 884, 931, 970]
#
# Rank: 69
# Nama Dokumen: Amr_bin_Ash.txt
# Skor Cosine Similarity: 0.04267680438997321
# Posisi Index untuk Kata dalam Query: [147, 320, 383, 510]
#
# Rank: 70
# Nama Dokumen: Surah_Ali_Imran.txt
# Skor Cosine Similarity: 0.04221559870444946
# Posisi Index untuk Kata dalam Query: [141, 258, 361, 379]
#
# Rank: 71
# Nama Dokumen: Syariat_Islam.txt
# Skor Cosine Similarity: 0.041839838322369476
# Posisi Index untuk Kata dalam Query: [181, 626, 778, 837, 1015, 1168]
#
# Rank: 72
# Nama Dokumen: Ibnul_Qayyim_al-Jauziyyah.txt
# Skor Cosine Similarity: 0.04116116061576795
# Posisi Index untuk Kata dalam Query: [51, 144, 192, 273, 419, 427]
#
# Rank: 73
# Nama Dokumen: Abdullah_bin_Zubair.txt
# Skor Cosine Similarity: 0.04114439597461879
# Posisi Index untuk Kata dalam Query: [60, 315, 395, 436, 456, 485, 914, 1378, 1398, 1433, 1704, 1731, 2371, 2396, 2597]
#
# Rank: 74
# Nama Dokumen: Surah_Luqman.txt
# Skor Cosine Similarity: 0.04046730172491153
# Posisi Index untuk Kata dalam Query: [271, 376, 483]
#
# Rank: 75
# Nama Dokumen: Muslim.txt
# Skor Cosine Similarity: 0.03964730855089328
# Posisi Index untuk Kata dalam Query: [331, 391, 401, 683]
#
# Rank: 76
# Nama Dokumen: Surah_Al-A_27raf.txt
# Skor Cosine Similarity: 0.03911607158131998
# Posisi Index untuk Kata dalam Query: [102, 497, 509]
#
# Rank: 77
# Nama Dokumen: Pertempuran_Nahrawan.txt
# Skor Cosine Similarity: 0.03905402115625003
# Posisi Index untuk Kata dalam Query: [237, 259]
#
# Rank: 78
# Nama Dokumen: Nabi_dan_rasul_dalam_Islam#Daftar_nabi_dan_rasul.txt
# Skor Cosine Similarity: 0.03862993054712063
# Posisi Index untuk Kata dalam Query: [90, 112, 115, 132, 543, 617, 641, 671, 877, 1043, 1619, 3503, 3685]
#
# Rank: 79
# Nama Dokumen: Salat_Tahajud.txt
# Skor Cosine Similarity: 0.03762207244717159
# Posisi Index untuk Kata dalam Query: [129, 133, 306, 548]
#
# Rank: 80
# Nama Dokumen: Asiyah.txt
# Skor Cosine Similarity: 0.03740261444137977
# Posisi Index untuk Kata dalam Query: [20, 481, 484, 733]
#
# Rank: 81
# Nama Dokumen: Surah_Qaf.txt
# Skor Cosine Similarity: 0.0372648348229506
# Posisi Index untuk Kata dalam Query: [45, 65, 81]
#
# Rank: 82
# Nama Dokumen: Perang_Saudara_Islam_I.txt
# Skor Cosine Similarity: 0.03702016825733845
# Posisi Index untuk Kata dalam Query: [233, 361, 528, 552, 1610, 1637, 1837, 1869, 1974]
#
# Rank: 83
# Nama Dokumen: Surah_Al-Anfal.txt
# Skor Cosine Similarity: 0.03699954290894861
# Posisi Index untuk Kata dalam Query: [308, 371]
#
# Rank: 84
# Nama Dokumen: Surah_Al-Ma_E2_80_99idah.txt
# Skor Cosine Similarity: 0.03493909196076584
# Posisi Index untuk Kata dalam Query: [52, 208, 526, 754, 781]
#
# Rank: 85
# Nama Dokumen: Makkah.txt
# Skor Cosine Similarity: 0.032755296732737624
# Posisi Index untuk Kata dalam Query: [105, 127, 1070, 1101, 1326, 1679]
#
# Rank: 86
# Nama Dokumen: Surah_An-Nisa_E2_80_99.txt
# Skor Cosine Similarity: 0.032025097746017306
# Posisi Index untuk Kata dalam Query: [64, 75, 1322, 1410, 1429, 1799]
#
# Rank: 87
# Nama Dokumen: Abdul_Muthalib.txt
# Skor Cosine Similarity: 0.030826569540566943
# Posisi Index untuk Kata dalam Query: [71, 829, 858, 859]
#
# Rank: 88
# Nama Dokumen: Surah_Al-Lail.txt
# Skor Cosine Similarity: 0.030443146070958507
# Posisi Index untuk Kata dalam Query: [253, 335, 449]
#
# Rank: 89
# Nama Dokumen: Pertempuran_Uhud.txt
# Skor Cosine Similarity: 0.03043914675310889
# Posisi Index untuk Kata dalam Query: [86, 809, 842, 896]
#
# Rank: 90
# Nama Dokumen: Al-Mustamsik.txt
# Skor Cosine Similarity: 0.030377483769395548
# Posisi Index untuk Kata dalam Query: [100, 154, 293]
#
# Rank: 91
# Nama Dokumen: Surah_Al-Fil.txt
# Skor Cosine Similarity: 0.030115651782114127
# Posisi Index untuk Kata dalam Query: [86]
#
# Rank: 92
# Nama Dokumen: Zikir.txt
# Skor Cosine Similarity: 0.029896405544885662
# Posisi Index untuk Kata dalam Query: [314, 336, 396, 652]
#
# Rank: 93
# Nama Dokumen: Rukun_iman.txt
# Skor Cosine Similarity: 0.029501876372371068
# Posisi Index untuk Kata dalam Query: [66, 109, 874, 1121]
#
# Rank: 94
# Nama Dokumen: Al-Mutawakkil_I.txt
# Skor Cosine Similarity: 0.028785824367780224
# Posisi Index untuk Kata dalam Query: [19]
#
# Rank: 95
# Nama Dokumen: Nasakh_(tafsir).txt
# Skor Cosine Similarity: 0.0285062375159238
# Posisi Index untuk Kata dalam Query: [129, 383, 578]
#
# Rank: 96
# Nama Dokumen: Haji.txt
# Skor Cosine Similarity: 0.028388556393759996
# Posisi Index untuk Kata dalam Query: [223, 618, 766, 792, 1065, 1287, 1798, 2297, 2600, 3365, 3703, 3779, 3851, 3934, 4125, 5093]
#
# Rank: 97
# Nama Dokumen: Salat_jenazah.txt
# Skor Cosine Similarity: 0.027961305866114585
# Posisi Index untuk Kata dalam Query: [43, 168, 363, 929, 968, 1006]
#
# Rank: 98
# Nama Dokumen: Surah_Al-A_E2_80_99la.txt
# Skor Cosine Similarity: 0.02723839429604241
# Posisi Index untuk Kata dalam Query: [132]
#
# Rank: 99
# Nama Dokumen: Surah_Al-Lahab.txt
# Skor Cosine Similarity: 0.027169959667268526
# Posisi Index untuk Kata dalam Query: [70, 176]
#
# Rank: 100
# Nama Dokumen: Allah.txt
# Skor Cosine Similarity: 0.027136828620497665
# Posisi Index untuk Kata dalam Query: [89, 102, 446, 505, 522, 751]
#
# Rank: 101
# Nama Dokumen: Syurahbil_bin_Hasanah.txt
# Skor Cosine Similarity: 0.026985749780779167
# Posisi Index untuk Kata dalam Query: [83, 110, 126]
#
# Rank: 102
# Nama Dokumen: Ibrahim.txt
# Skor Cosine Similarity: 0.02630898776958278
# Posisi Index untuk Kata dalam Query: [135, 261, 3278, 3574, 3642, 3654, 3684, 3690, 4308, 4872, 4955, 4983, 4989, 5003]
#
# Rank: 103
# Nama Dokumen: Kekhalifahan_Umayyah#Daftar_Khalifah.txt
# Skor Cosine Similarity: 0.02594194434985032
# Posisi Index untuk Kata dalam Query: [143, 1378, 1447, 2163, 2190, 2210, 2227]
#
# Rank: 104
# Nama Dokumen: Sunnah.txt
# Skor Cosine Similarity: 0.02552507985101233
# Posisi Index untuk Kata dalam Query: [121]
#
# Rank: 105
# Nama Dokumen: Muawiyah_bin_Abu_Sufyan.txt
# Skor Cosine Similarity: 0.024858725970469196
# Posisi Index untuk Kata dalam Query: [53, 366, 385, 390, 468, 705, 711, 1775, 1946, 2097, 3421, 3734, 3740, 5445, 5752, 5773, 5786, 5891]
#
# Rank: 106
# Nama Dokumen: Surah_Quraisy.txt
# Skor Cosine Similarity: 0.02472053816897091
# Posisi Index untuk Kata dalam Query: [50]
#
# Rank: 107
# Nama Dokumen: Marwan_bin_al-Hakam.txt
# Skor Cosine Similarity: 0.024017831748190634
# Posisi Index untuk Kata dalam Query: [297, 400, 411, 866, 1303, 1322, 2724, 3030, 3247, 3345, 3555, 4122]
#
# Rank: 108
# Nama Dokumen: Surah__27Abasa.txt
# Skor Cosine Similarity: 0.02250345837985999
# Posisi Index untuk Kata dalam Query: [154, 164]
#
# Rank: 109
# Nama Dokumen: Surah_Al-Fatihah.txt
# Skor Cosine Similarity: 0.022389464092216285
# Posisi Index untuk Kata dalam Query: [496, 535, 751, 892]
#
# Rank: 110
# Nama Dokumen: Zakat.txt
# Skor Cosine Similarity: 0.022206201426038765
# Posisi Index untuk Kata dalam Query: [256, 687, 832, 939, 1274, 1867]
#
# Rank: 111
# Nama Dokumen: Ilyas.txt
# Skor Cosine Similarity: 0.022129941895683215
# Posisi Index untuk Kata dalam Query: [922, 1038, 1047, 1065, 1069, 1635]
#
# Rank: 112
# Nama Dokumen: Ibnu_Rajab.txt
# Skor Cosine Similarity: 0.021648270935337874
# Posisi Index untuk Kata dalam Query: [74, 173]
#
# Rank: 113
# Nama Dokumen: Surah_An-Nasr.txt
# Skor Cosine Similarity: 0.021629264026603458
# Posisi Index untuk Kata dalam Query: [161]
#
# Rank: 114
# Nama Dokumen: Al-Barbahari.txt
# Skor Cosine Similarity: 0.02117414842855874
# Posisi Index untuk Kata dalam Query: [70]
#
# Rank: 115
# Nama Dokumen: Syits.txt
# Skor Cosine Similarity: 0.021042022403351113
# Posisi Index untuk Kata dalam Query: [462, 483, 787]
#
# Rank: 116
# Nama Dokumen: Ulama.txt
# Skor Cosine Similarity: 0.021022419112265302
# Posisi Index untuk Kata dalam Query: [171]
#
# Rank: 117
# Nama Dokumen: Umar_bin_Abdul_Aziz.txt
# Skor Cosine Similarity: 0.020493256114313598
# Posisi Index untuk Kata dalam Query: [626, 686, 1819, 1921, 1996, 2041, 2141, 2582]
#
# Rank: 118
# Nama Dokumen: Ismail.txt
# Skor Cosine Similarity: 0.02038952613487798
# Posisi Index untuk Kata dalam Query: [57, 87, 1591, 2097, 2342, 2520, 2597, 2603, 2617]
#
# Rank: 119
# Nama Dokumen: Surah_Al-Muzzammil.txt
# Skor Cosine Similarity: 0.020323422893790025
# Posisi Index untuk Kata dalam Query: [56]
#
# Rank: 120
# Nama Dokumen: Yazid_bin_Abdul-Malik.txt
# Skor Cosine Similarity: 0.02030797554718211
# Posisi Index untuk Kata dalam Query: [976, 1051, 1099, 1145, 1518]
#
# Rank: 121
# Nama Dokumen: Surah_Al-_27Alaq.txt
# Skor Cosine Similarity: 0.020134876923615652
# Posisi Index untuk Kata dalam Query: [52]
#
# Rank: 122
# Nama Dokumen: Tauhid.txt
# Skor Cosine Similarity: 0.019827563441886978
# Posisi Index untuk Kata dalam Query: [56, 1332, 1354]
#
# Rank: 123
# Nama Dokumen: Surah_Al-Kafirun.txt
# Skor Cosine Similarity: 0.01943187446853856
# Posisi Index untuk Kata dalam Query: [69]
#
# Rank: 124
# Nama Dokumen: Haram.txt
# Skor Cosine Similarity: 0.019093510089486718
# Posisi Index untuk Kata dalam Query: [247]
#
# Rank: 125
# Nama Dokumen: Ibadah.txt
# Skor Cosine Similarity: 0.01877738065788318
# Posisi Index untuk Kata dalam Query: [163]
#
# Rank: 126
# Nama Dokumen: Ahmad_bin_Hanbal.txt
# Skor Cosine Similarity: 0.018742846694551098
# Posisi Index untuk Kata dalam Query: [187, 1006, 1392, 1791]
#
# Rank: 127
# Nama Dokumen: Al-Mutawakkil_III.txt
# Skor Cosine Similarity: 0.018206942135364113
# Posisi Index untuk Kata dalam Query: [17, 41]
#
# Rank: 128
# Nama Dokumen: Kekhalifahan_Abbasiyah#Kekhalifahan_Abbasiyah_di_Kairo.txt
# Skor Cosine Similarity: 0.017861667946191397
# Posisi Index untuk Kata dalam Query: [77, 435, 637, 722, 1135, 2521, 4767, 6526, 7108, 7375, 7414, 7425]
#
# Rank: 129
# Nama Dokumen: Surah_Ghafir.txt
# Skor Cosine Similarity: 0.01774947343470183
# Posisi Index untuk Kata dalam Query: [102]
#
# Rank: 130
# Nama Dokumen: Al-Mustanshir_II.txt
# Skor Cosine Similarity: 0.01770476119791529
# Posisi Index untuk Kata dalam Query: [188, 495]
#
# Rank: 131
# Nama Dokumen: Zul_Qarnain.txt
# Skor Cosine Similarity: 0.017454071363647548
# Posisi Index untuk Kata dalam Query: [139, 303, 1659, 1668, 1673]
#
# Rank: 132
# Nama Dokumen: Abdul_Malik_bin_Marwan.txt
# Skor Cosine Similarity: 0.01626968251053452
# Posisi Index untuk Kata dalam Query: [547, 1193, 1855, 2090, 2120, 3170, 3775]
#
# Rank: 133
# Nama Dokumen: Al-Qurthubi.txt
# Skor Cosine Similarity: 0.01570056278221558
# Posisi Index untuk Kata dalam Query: [32]
#
# Rank: 134
# Nama Dokumen: Surah_Ar-Ra_E2_80_99d.txt
# Skor Cosine Similarity: 0.015609694008816946
# Posisi Index untuk Kata dalam Query: [192]
#
# Rank: 135
# Nama Dokumen: Salat_Istikharah.txt
# Skor Cosine Similarity: 0.015209277775758891
# Posisi Index untuk Kata dalam Query: [85]
#
# Rank: 136
# Nama Dokumen: Ijmak.txt
# Skor Cosine Similarity: 0.015095996127824907
# Posisi Index untuk Kata dalam Query: [121, 174, 546]
#
# Rank: 137
# Nama Dokumen: Jihad.txt
# Skor Cosine Similarity: 0.014833901361873115
# Posisi Index untuk Kata dalam Query: [661, 673]
#
# Rank: 138
# Nama Dokumen: Mazhab.txt
# Skor Cosine Similarity: 0.014665278491198188
# Posisi Index untuk Kata dalam Query: [227, 484]
#
# Rank: 139
# Nama Dokumen: Surah_Yusuf.txt
# Skor Cosine Similarity: 0.014602979481912056
# Posisi Index untuk Kata dalam Query: [61, 74]
#
# Rank: 140
# Nama Dokumen: Malaikat.txt
# Skor Cosine Similarity: 0.014413199674189992
# Posisi Index untuk Kata dalam Query: [355, 416, 646, 818]
#
# Rank: 141
# Nama Dokumen: Ishak_dalam_Islam.txt
# Skor Cosine Similarity: 0.014255831120668257
# Posisi Index untuk Kata dalam Query: [65, 1391, 1601]
#
# Rank: 142
# Nama Dokumen: Surah_As-Sajdah.txt
# Skor Cosine Similarity: 0.013954810621152374
# Posisi Index untuk Kata dalam Query: [63]
#
# Rank: 143
# Nama Dokumen: Yunus.txt
# Skor Cosine Similarity: 0.013713001760820858
# Posisi Index untuk Kata dalam Query: [2301, 2308, 2319, 2358, 2367, 2389, 2393, 2410, 2415]
#
# Rank: 144
# Nama Dokumen: Al-Biruni.txt
# Skor Cosine Similarity: 0.013274513304481868
# Posisi Index untuk Kata dalam Query: [17]
#
# Rank: 145
# Nama Dokumen: Madaniyah.txt
# Skor Cosine Similarity: 0.013046824366021333
# Posisi Index untuk Kata dalam Query: [68]
#
# Rank: 146
# Nama Dokumen: Surah_Ad-Dukhan.txt
# Skor Cosine Similarity: 0.012891764755471342
# Posisi Index untuk Kata dalam Query: [60]
#
# Rank: 147
# Nama Dokumen: Salat_tahiyat_masjid.txt
# Skor Cosine Similarity: 0.012837018908448936
# Posisi Index untuk Kata dalam Query: [281]
#
# Rank: 148
# Nama Dokumen: Haji_wadak.txt
# Skor Cosine Similarity: 0.012697745185820461
# Posisi Index untuk Kata dalam Query: [27, 43]
#
# Rank: 149
# Nama Dokumen: Isa.txt
# Skor Cosine Similarity: 0.012690607048621553
# Posisi Index untuk Kata dalam Query: [96, 4240, 4325, 4349, 4582, 4784, 5510, 5755, 6201]
#
# Rank: 150
# Nama Dokumen: Surah_Al-Qamar.txt
# Skor Cosine Similarity: 0.012645233169552038
# Posisi Index untuk Kata dalam Query: [52]
#
# Rank: 151
# Nama Dokumen: Ushul_Fikih.txt
# Skor Cosine Similarity: 0.01262868971990396
# Posisi Index untuk Kata dalam Query: [190]
#
# Rank: 152
# Nama Dokumen: Maryam.txt
# Skor Cosine Similarity: 0.012575478210000183
# Posisi Index untuk Kata dalam Query: [1746, 2048, 2160, 2313]
#
# Rank: 153
# Nama Dokumen: Jinayah.txt
# Skor Cosine Similarity: 0.012146717427608271
# Posisi Index untuk Kata dalam Query: [1403, 1423, 1468]
#
# Rank: 154
# Nama Dokumen: Zulkifli.txt
# Skor Cosine Similarity: 0.011928789064175873
# Posisi Index untuk Kata dalam Query: [1051, 1073]
#
# Rank: 155
# Nama Dokumen: Yazid_bin_Muawiyah.txt
# Skor Cosine Similarity: 0.011593460541689703
# Posisi Index untuk Kata dalam Query: [101, 1670, 1873]
#
# Rank: 156
# Nama Dokumen: Abu_Lu_u_ah.txt
# Skor Cosine Similarity: 0.011493008832367705
# Posisi Index untuk Kata dalam Query: [181, 1126, 1296]
#
# Rank: 157
# Nama Dokumen: Neraka.txt
# Skor Cosine Similarity: 0.011454277438262639
# Posisi Index untuk Kata dalam Query: [71, 496, 650]
#
# Rank: 158
# Nama Dokumen: Salat_lima_waktu.txt
# Skor Cosine Similarity: 0.011440335057486603
# Posisi Index untuk Kata dalam Query: [843, 1083, 1917]
#
# Rank: 159
# Nama Dokumen: Akidah_Islam.txt
# Skor Cosine Similarity: 0.011402691243050926
# Posisi Index untuk Kata dalam Query: [41]
#
# Rank: 160
# Nama Dokumen: Pertempuran_Yamamah.txt
# Skor Cosine Similarity: 0.011393908523279381
# Posisi Index untuk Kata dalam Query: [43]
#
# Rank: 161
# Nama Dokumen: Iman.txt
# Skor Cosine Similarity: 0.011020257574339677
# Posisi Index untuk Kata dalam Query: [60]
#
# Rank: 162
# Nama Dokumen: Surah_Al-Mu_E2_80_99minun.txt
# Skor Cosine Similarity: 0.010903845000981242
# Posisi Index untuk Kata dalam Query: [72, 185]
#
# Rank: 163
# Nama Dokumen: Ibnu_Taimiyah.txt
# Skor Cosine Similarity: 0.010805729181240967
# Posisi Index untuk Kata dalam Query: [76]
#
# Rank: 164
# Nama Dokumen: Saleh.txt
# Skor Cosine Similarity: 0.010368350549558623
# Posisi Index untuk Kata dalam Query: [1310, 1370]
#
# Rank: 165
# Nama Dokumen: Surah_Al-Ahqaf.txt
# Skor Cosine Similarity: 0.009263754912020371
# Posisi Index untuk Kata dalam Query: [1025]
#
# Rank: 166
# Nama Dokumen: Wabah_Amwas.txt
# Skor Cosine Similarity: 0.009058897105993632
# Posisi Index untuk Kata dalam Query: [781, 855, 2400]
#
# Rank: 167
# Nama Dokumen: Surah_al-Anbiya_27.txt
# Skor Cosine Similarity: 0.009009130847364788
# Posisi Index untuk Kata dalam Query: [71, 124]
#
# Rank: 168
# Nama Dokumen: Ilyasa.txt
# Skor Cosine Similarity: 0.008591690263919084
# Posisi Index untuk Kata dalam Query: [219, 1338]
#
# Rank: 169
# Nama Dokumen: Surah_Asy-Syu_27ara.txt
# Skor Cosine Similarity: 0.00821442010810707
# Posisi Index untuk Kata dalam Query: [80, 161]
#
# Rank: 170
# Nama Dokumen: Surah_Al-Hijr.txt
# Skor Cosine Similarity: 0.007869704415118542
# Posisi Index untuk Kata dalam Query: [198]
#
# Rank: 171
# Nama Dokumen: Salat_Duha.txt
# Skor Cosine Similarity: 0.007516165697718331
# Posisi Index untuk Kata dalam Query: [588]
#
# Rank: 172
# Nama Dokumen: Musa.txt
# Skor Cosine Similarity: 0.007461342850561033
# Posisi Index untuk Kata dalam Query: [4539, 6707, 6743, 6793, 6855, 7564]
#
# Rank: 173
# Nama Dokumen: Pertempuran_Shiffin.txt
# Skor Cosine Similarity: 0.007359355806425376
# Posisi Index untuk Kata dalam Query: [155]
#
# Rank: 174
# Nama Dokumen: Yahya.txt
# Skor Cosine Similarity: 0.007328599105810253
# Posisi Index untuk Kata dalam Query: [1531, 2036]
#
# Rank: 175
# Nama Dokumen: Al-Mustakfi_II.txt
# Skor Cosine Similarity: 0.0072613627514589415
# Posisi Index untuk Kata dalam Query: [293]
#
# Rank: 176
# Nama Dokumen: Surah_Ar-Rum.txt
# Skor Cosine Similarity: 0.007192144793563647
# Posisi Index untuk Kata dalam Query: [90]
#
# Rank: 177
# Nama Dokumen: Syuaib.txt
# Skor Cosine Similarity: 0.007139502506835018
# Posisi Index untuk Kata dalam Query: [805, 1428]
#
# Rank: 178
# Nama Dokumen: Akhirat.txt
# Skor Cosine Similarity: 0.006164249179559767
# Posisi Index untuk Kata dalam Query: [373]
#
# Rank: 179
# Nama Dokumen: Surah_Maryam.txt
# Skor Cosine Similarity: 0.0060896106808785355
# Posisi Index untuk Kata dalam Query: [41]
#
# Rank: 180
# Nama Dokumen: Sara.txt
# Skor Cosine Similarity: 0.0056756290694646
# Posisi Index untuk Kata dalam Query: [1640, 2097]
#
# Rank: 181
# Nama Dokumen: Al-Walid_bin_Abdul-Malik.txt
# Skor Cosine Similarity: 0.00563033524844669
# Posisi Index untuk Kata dalam Query: [340]
#
# Rank: 182
# Nama Dokumen: Hajar.txt
# Skor Cosine Similarity: 0.0054745581493562305
# Posisi Index untuk Kata dalam Query: [1170]
#
# Rank: 183
# Nama Dokumen: Yusuf_dalam_Islam.txt
# Skor Cosine Similarity: 0.005386107861575467
# Posisi Index untuk Kata dalam Query: [1041, 2169, 4438, 5188]
#
# Rank: 184
# Nama Dokumen: Lut.txt
# Skor Cosine Similarity: 0.005360721246422036
# Posisi Index untuk Kata dalam Query: [1860, 2129]
#
# Rank: 185
# Nama Dokumen: Daud_dalam_Islam.txt
# Skor Cosine Similarity: 0.005302330849477596
# Posisi Index untuk Kata dalam Query: [2011, 2256]
#
# Rank: 186
# Nama Dokumen: Hud.txt
# Skor Cosine Similarity: 0.0048286390821872865
# Posisi Index untuk Kata dalam Query: [1345]
#
# Rank: 187
# Nama Dokumen: Zakariyya.txt
# Skor Cosine Similarity: 0.004749729858598186
# Posisi Index untuk Kata dalam Query: [1328]
#
# Rank: 188
# Nama Dokumen: Adam.txt
# Skor Cosine Similarity: 0.004673955747816533
# Posisi Index untuk Kata dalam Query: [3349, 3434]
#
# Rank: 189
# Nama Dokumen: Surah_Al-Qasas.txt
# Skor Cosine Similarity: 0.004661934320097116
# Posisi Index untuk Kata dalam Query: [121]
#
# Rank: 190
# Nama Dokumen: Harun_(tokoh_Al-Qur_an).txt
# Skor Cosine Similarity: 0.004571002051891097
# Posisi Index untuk Kata dalam Query: [2788, 2993]
#
# Rank: 191
# Nama Dokumen: Yakub_(tokoh_Al-Qur_an).txt
# Skor Cosine Similarity: 0.004405796741505177
# Posisi Index untuk Kata dalam Query: [2332, 2725]
#
# Rank: 192
# Nama Dokumen: Surah_Al-Ahzab.txt
# Skor Cosine Similarity: 0.004375229712717215
# Posisi Index untuk Kata dalam Query: [1078]
#
# Rank: 193
# Nama Dokumen: Ayub_(tokoh_Al-Qur_an).txt
# Skor Cosine Similarity: 0.004294859677890266
# Posisi Index untuk Kata dalam Query: [1398, 2120]
#
# Rank: 194
# Nama Dokumen: Hawa.txt
# Skor Cosine Similarity: 0.0034573670609282137
# Posisi Index untuk Kata dalam Query: [1874]
#
# Rank: 195
# Nama Dokumen: Nuh_(tokoh_Alkitab).txt
# Skor Cosine Similarity: 0.003135289870670796
# Posisi Index untuk Kata dalam Query: [2437]
#
# Rank: 196
# Nama Dokumen: Sulaiman.txt
# Skor Cosine Similarity: 0.0020942418584355207
# Posisi Index untuk Kata dalam Query: [2440]
#
# Rank: 197
# Nama Dokumen: Ibnu_Sina.txt
# Skor Cosine Similarity: 0.001758644924904239
# Posisi Index untuk Kata dalam Query: [399]
#
# Dokumen teratas berdasarkan Jaccard Similarity:
# Rank: 1
# Nama Dokumen: Madaniyah.txt
# Skor Jaccard Similarity: 0.013157894736842105
# Posisi Index untuk Kata dalam Query: [68]
#
# Rank: 2
# Nama Dokumen: Khalid_bin_Sa_id.txt
# Skor Jaccard Similarity: 0.011904761904761904
# Posisi Index untuk Kata dalam Query: [34, 72]
#
# Rank: 3
# Nama Dokumen: Al-Mutawakkil_I.txt
# Skor Jaccard Similarity: 0.011494252873563218
# Posisi Index untuk Kata dalam Query: [19]
#
# Rank: 4
# Nama Dokumen: Penutup_Para_Nabi.txt
# Skor Jaccard Similarity: 0.010526315789473684
# Posisi Index untuk Kata dalam Query: [30, 37, 47, 95, 119]
#
# Rank: 5
# Nama Dokumen: Bani_Taim.txt
# Skor Jaccard Similarity: 0.008849557522123894
# Posisi Index untuk Kata dalam Query: [55, 127, 157, 167]
#
# Rank: 6
# Nama Dokumen: Surah_Al-Fil.txt
# Skor Jaccard Similarity: 0.008333333333333333
# Posisi Index untuk Kata dalam Query: [86]
#
# Rank: 7
# Nama Dokumen: Yazid_bin_Walid.txt
# Skor Jaccard Similarity: 0.007751937984496124
# Posisi Index untuk Kata dalam Query: [80, 86, 113]
#
# Rank: 8
# Nama Dokumen: Surah_Ghafir.txt
# Skor Jaccard Similarity: 0.007692307692307693
# Posisi Index untuk Kata dalam Query: [102]
#
# Rank: 9
# Nama Dokumen: Pertempuran_Yamamah.txt
# Skor Jaccard Similarity: 0.007518796992481203
# Posisi Index untuk Kata dalam Query: [43]
#
# Rank: 10
# Nama Dokumen: Surah_Quraisy.txt
# Skor Jaccard Similarity: 0.007518796992481203
# Posisi Index untuk Kata dalam Query: [50]
#
# Rank: 11
# Nama Dokumen: Pertempuran_Zaturriqa.txt
# Skor Jaccard Similarity: 0.007246376811594203
# Posisi Index untuk Kata dalam Query: [53, 134, 149, 161, 165]
#
# Rank: 12
# Nama Dokumen: Pengepungan_Tha_if.txt
# Skor Jaccard Similarity: 0.0070921985815602835
# Posisi Index untuk Kata dalam Query: [85, 136, 198]
#
# Rank: 13
# Nama Dokumen: Sunnah.txt
# Skor Jaccard Similarity: 0.007042253521126761
# Posisi Index untuk Kata dalam Query: [121]
#
# Rank: 14
# Nama Dokumen: Surah_An-Nasr.txt
# Skor Jaccard Similarity: 0.006896551724137931
# Posisi Index untuk Kata dalam Query: [161]
#
# Rank: 15
# Nama Dokumen: Surah_Al-Kafirun.txt
# Skor Jaccard Similarity: 0.006711409395973154
# Posisi Index untuk Kata dalam Query: [69]
#
# Rank: 16
# Nama Dokumen: Surah_Asy-Syarh.txt
# Skor Jaccard Similarity: 0.006711409395973154
# Posisi Index untuk Kata dalam Query: [87, 118, 132, 146]
#
# Rank: 17
# Nama Dokumen: Surah_Al-Kausar.txt
# Skor Jaccard Similarity: 0.006622516556291391
# Posisi Index untuk Kata dalam Query: [99, 165, 193, 202, 219]
#
# Rank: 18
# Nama Dokumen: Surah_Al-_27Alaq.txt
# Skor Jaccard Similarity: 0.006578947368421052
# Posisi Index untuk Kata dalam Query: [52]
#
# Rank: 19
# Nama Dokumen: Ekspedisi_Tabuk.txt
# Skor Jaccard Similarity: 0.006369426751592357
# Posisi Index untuk Kata dalam Query: [30, 70, 87, 103, 134, 143, 155, 161, 189]
#
# Rank: 20
# Nama Dokumen: Marwan_bin_Muhammad.txt
# Skor Jaccard Similarity: 0.006369426751592357
# Posisi Index untuk Kata dalam Query: [8, 12, 26, 58, 221]
#
# Rank: 21
# Nama Dokumen: Surah_Al-Lahab.txt
# Skor Jaccard Similarity: 0.006369426751592357
# Posisi Index untuk Kata dalam Query: [70, 176]
#
# Rank: 22
# Nama Dokumen: Haram.txt
# Skor Jaccard Similarity: 0.005917159763313609
# Posisi Index untuk Kata dalam Query: [247]
#
# Rank: 23
# Nama Dokumen: Al-Qurthubi.txt
# Skor Jaccard Similarity: 0.005813953488372093
# Posisi Index untuk Kata dalam Query: [32]
#
# Rank: 24
# Nama Dokumen: Surah_Al-A_E2_80_99la.txt
# Skor Jaccard Similarity: 0.005813953488372093
# Posisi Index untuk Kata dalam Query: [132]
#
# Rank: 25
# Nama Dokumen: Ibadah.txt
# Skor Jaccard Similarity: 0.005747126436781609
# Posisi Index untuk Kata dalam Query: [163]
#
# Rank: 26
# Nama Dokumen: Salat_Istikharah.txt
# Skor Jaccard Similarity: 0.005714285714285714
# Posisi Index untuk Kata dalam Query: [85]
#
# Rank: 27
# Nama Dokumen: Al-Barbahari.txt
# Skor Jaccard Similarity: 0.005681818181818182
# Posisi Index untuk Kata dalam Query: [70]
#
# Rank: 28
# Nama Dokumen: Abdullah_bin_Abdul_Muthalib.txt
# Skor Jaccard Similarity: 0.005649717514124294
# Posisi Index untuk Kata dalam Query: [40, 50, 64, 73, 281]
#
# Rank: 29
# Nama Dokumen: Hakim_an-Naisaburi.txt
# Skor Jaccard Similarity: 0.005405405405405406
# Posisi Index untuk Kata dalam Query: [50, 84, 88, 170]
#
# Rank: 30
# Nama Dokumen: Al-Walid_bin_Yazid.txt
# Skor Jaccard Similarity: 0.0053475935828877
# Posisi Index untuk Kata dalam Query: [129, 131, 160, 164, 206, 285, 303]
#
# Rank: 31
# Nama Dokumen: Ibnu_Khuzaimah.txt
# Skor Jaccard Similarity: 0.0053475935828877
# Posisi Index untuk Kata dalam Query: [102, 148, 192, 197, 202, 252]
#
# Rank: 32
# Nama Dokumen: Surah_Ad-Duha.txt
# Skor Jaccard Similarity: 0.005235602094240838
# Posisi Index untuk Kata dalam Query: [58, 104, 128, 158, 251, 265]
#
# Rank: 33
# Nama Dokumen: Al-Biruni.txt
# Skor Jaccard Similarity: 0.0048543689320388345
# Posisi Index untuk Kata dalam Query: [17]
#
# Rank: 34
# Nama Dokumen: Hijrah_ke_Abisinia.txt
# Skor Jaccard Similarity: 0.004761904761904762
# Posisi Index untuk Kata dalam Query: [47, 130, 153]
#
# Rank: 35
# Nama Dokumen: Pertempuran_Nahrawan.txt
# Skor Jaccard Similarity: 0.004761904761904762
# Posisi Index untuk Kata dalam Query: [237, 259]
#
# Rank: 36
# Nama Dokumen: Salat_tahiyat_masjid.txt
# Skor Jaccard Similarity: 0.004694835680751174
# Posisi Index untuk Kata dalam Query: [281]
#
# Rank: 37
# Nama Dokumen: Ulama.txt
# Skor Jaccard Similarity: 0.004629629629629629
# Posisi Index untuk Kata dalam Query: [171]
#
# Rank: 38
# Nama Dokumen: Surah_Al-Muzzammil.txt
# Skor Jaccard Similarity: 0.004484304932735426
# Posisi Index untuk Kata dalam Query: [56]
#
# Rank: 39
# Nama Dokumen: Perjanjian_Hudaibiyyah.txt
# Skor Jaccard Similarity: 0.004405286343612335
# Posisi Index untuk Kata dalam Query: [147, 162, 253, 268, 284, 298, 469, 470]
#
# Rank: 40
# Nama Dokumen: Ushul_Fikih.txt
# Skor Jaccard Similarity: 0.004366812227074236
# Posisi Index untuk Kata dalam Query: [190]
#
# Rank: 41
# Nama Dokumen: Rasul.txt
# Skor Jaccard Similarity: 0.004201680672268907
# Posisi Index untuk Kata dalam Query: [53, 118, 131, 167, 189, 238, 263]
#
# Rank: 42
# Nama Dokumen: Ibnu_Hazm.txt
# Skor Jaccard Similarity: 0.00411522633744856
# Posisi Index untuk Kata dalam Query: [79, 172, 344]
#
# Rank: 43
# Nama Dokumen: Surah_Al-Anfal.txt
# Skor Jaccard Similarity: 0.003875968992248062
# Posisi Index untuk Kata dalam Query: [308, 371]
#
# Rank: 44
# Nama Dokumen: Surah_An-N_C4_81s.txt
# Skor Jaccard Similarity: 0.003875968992248062
# Posisi Index untuk Kata dalam Query: [186, 302, 314, 359]
#
# Rank: 45
# Nama Dokumen: Abu_al-Hasan_al-Asy_ari.txt
# Skor Jaccard Similarity: 0.0038461538461538464
# Posisi Index untuk Kata dalam Query: [215, 234, 235, 255, 262, 284, 286, 315]
#
# Rank: 46
# Nama Dokumen: Salat_Tahajud.txt
# Skor Jaccard Similarity: 0.0038314176245210726
# Posisi Index untuk Kata dalam Query: [129, 133, 306, 548]
#
# Rank: 47
# Nama Dokumen: Surah_Ar-Ra_E2_80_99d.txt
# Skor Jaccard Similarity: 0.0037735849056603774
# Posisi Index untuk Kata dalam Query: [192]
#
# Rank: 48
# Nama Dokumen: Pertempuran_Hunain.txt
# Skor Jaccard Similarity: 0.0037313432835820895
# Posisi Index untuk Kata dalam Query: [22, 79, 100, 111, 152, 234, 280, 483]
#
# Rank: 49
# Nama Dokumen: Iman.txt
# Skor Jaccard Similarity: 0.0035842293906810036
# Posisi Index untuk Kata dalam Query: [60]
#
# Rank: 50
# Nama Dokumen: Surah_Luqman.txt
# Skor Jaccard Similarity: 0.0035587188612099642
# Posisi Index untuk Kata dalam Query: [271, 376, 483]
#
# Rank: 51
# Nama Dokumen: Surah_Al-An_27am.txt
# Skor Jaccard Similarity: 0.0035335689045936395
# Posisi Index untuk Kata dalam Query: [162, 180, 230, 266]
#
# Rank: 52
# Nama Dokumen: Surah_Al-Lail.txt
# Skor Jaccard Similarity: 0.003424657534246575
# Posisi Index untuk Kata dalam Query: [253, 335, 449]
#
# Rank: 53
# Nama Dokumen: Al-Mustamsik.txt
# Skor Jaccard Similarity: 0.0033222591362126247
# Posisi Index untuk Kata dalam Query: [100, 154, 293]
#
# Rank: 54
# Nama Dokumen: Ijmak.txt
# Skor Jaccard Similarity: 0.0033112582781456954
# Posisi Index untuk Kata dalam Query: [121, 174, 546]
#
# Rank: 55
# Nama Dokumen: Surah_Al-Qamar.txt
# Skor Jaccard Similarity: 0.0032258064516129032
# Posisi Index untuk Kata dalam Query: [52]
#
# Rank: 56
# Nama Dokumen: Surah__27Abasa.txt
# Skor Jaccard Similarity: 0.003205128205128205
# Posisi Index untuk Kata dalam Query: [154, 164]
#
# Rank: 57
# Nama Dokumen: Ibnu_Rajab.txt
# Skor Jaccard Similarity: 0.0031645569620253164
# Posisi Index untuk Kata dalam Query: [74, 173]
#
# Rank: 58
# Nama Dokumen: Surah_Al-A_27raf.txt
# Skor Jaccard Similarity: 0.0031446540880503146
# Posisi Index untuk Kata dalam Query: [102, 497, 509]
#
# Rank: 59
# Nama Dokumen: Surah_As-Sajdah.txt
# Skor Jaccard Similarity: 0.003134796238244514
# Posisi Index untuk Kata dalam Query: [63]
#
# Rank: 60
# Nama Dokumen: Surah_Al-Ikhlas.txt
# Skor Jaccard Similarity: 0.003125
# Posisi Index untuk Kata dalam Query: [183, 205, 273, 371, 537, 601, 668, 701]
#
# Rank: 61
# Nama Dokumen: Surah_Ad-Dukhan.txt
# Skor Jaccard Similarity: 0.0030864197530864196
# Posisi Index untuk Kata dalam Query: [60]
#
# Rank: 62
# Nama Dokumen: Akidah_Islam.txt
# Skor Jaccard Similarity: 0.0029850746268656717
# Posisi Index untuk Kata dalam Query: [41]
#
# Rank: 63
# Nama Dokumen: Asiyah.txt
# Skor Jaccard Similarity: 0.002898550724637681
# Posisi Index untuk Kata dalam Query: [20, 481, 484, 733]
#
# Rank: 64
# Nama Dokumen: Surah_Qaf.txt
# Skor Jaccard Similarity: 0.002857142857142857
# Posisi Index untuk Kata dalam Query: [45, 65, 81]
#
# Rank: 65
# Nama Dokumen: Surah_Yusuf.txt
# Skor Jaccard Similarity: 0.002849002849002849
# Posisi Index untuk Kata dalam Query: [61, 74]
#
# Rank: 66
# Nama Dokumen: Zikir.txt
# Skor Jaccard Similarity: 0.002840909090909091
# Posisi Index untuk Kata dalam Query: [314, 336, 396, 652]
#
# Rank: 67
# Nama Dokumen: Surah_Al-Fath.txt
# Skor Jaccard Similarity: 0.002824858757062147
# Posisi Index untuk Kata dalam Query: [55, 58, 88, 94, 867, 986]
#
# Rank: 68
# Nama Dokumen: Syurahbil_bin_Hasanah.txt
# Skor Jaccard Similarity: 0.0028089887640449437
# Posisi Index untuk Kata dalam Query: [83, 110, 126]
#
# Rank: 69
# Nama Dokumen: Surah_Muhammad.txt
# Skor Jaccard Similarity: 0.002785515320334262
# Posisi Index untuk Kata dalam Query: [7, 10, 19, 27, 43, 48, 70, 80, 96, 157, 946]
#
# Rank: 70
# Nama Dokumen: Mazhab.txt
# Skor Jaccard Similarity: 0.002777777777777778
# Posisi Index untuk Kata dalam Query: [227, 484]
#
# Rank: 71
# Nama Dokumen: Amr_bin_Ash.txt
# Skor Jaccard Similarity: 0.0027548209366391185
# Posisi Index untuk Kata dalam Query: [147, 320, 383, 510]
#
# Rank: 72
# Nama Dokumen: Surah_Yasin.txt
# Skor Jaccard Similarity: 0.002652519893899204
# Posisi Index untuk Kata dalam Query: [110, 173, 212, 219, 238, 273, 282, 642, 759, 761, 772]
#
# Rank: 73
# Nama Dokumen: Salat_Duha.txt
# Skor Jaccard Similarity: 0.0026109660574412533
# Posisi Index untuk Kata dalam Query: [588]
#
# Rank: 74
# Nama Dokumen: Nasakh_(tafsir).txt
# Skor Jaccard Similarity: 0.0026041666666666665
# Posisi Index untuk Kata dalam Query: [129, 383, 578]
#
# Rank: 75
# Nama Dokumen: Surah_Yunus.txt
# Skor Jaccard Similarity: 0.0026041666666666665
# Posisi Index untuk Kata dalam Query: [123, 220, 353, 363, 373, 405, 407, 515]
#
# Rank: 76
# Nama Dokumen: Salaf.txt
# Skor Jaccard Similarity: 0.0025906735751295338
# Posisi Index untuk Kata dalam Query: [237, 262, 304, 307, 310, 314, 320, 742]
#
# Rank: 77
# Nama Dokumen: Surah_Al-Ahqaf.txt
# Skor Jaccard Similarity: 0.002583979328165375
# Posisi Index untuk Kata dalam Query: [1025]
#
# Rank: 78
# Nama Dokumen: Jihad.txt
# Skor Jaccard Similarity: 0.002577319587628866
# Posisi Index untuk Kata dalam Query: [661, 673]
#
# Rank: 79
# Nama Dokumen: Al-Mutawakkil_III.txt
# Skor Jaccard Similarity: 0.002564102564102564
# Posisi Index untuk Kata dalam Query: [17, 41]
#
# Rank: 80
# Nama Dokumen: Muslim.txt
# Skor Jaccard Similarity: 0.0025188916876574307
# Posisi Index untuk Kata dalam Query: [331, 391, 401, 683]
#
# Rank: 81
# Nama Dokumen: Hijrah.txt
# Skor Jaccard Similarity: 0.0024630541871921183
# Posisi Index untuk Kata dalam Query: [21, 39, 57, 343, 347, 360, 372, 398, 428, 463, 505, 534, 586, 617, 639, 656, 707]
#
# Rank: 82
# Nama Dokumen: Syits.txt
# Skor Jaccard Similarity: 0.0024330900243309003
# Posisi Index untuk Kata dalam Query: [462, 483, 787]
#
# Rank: 83
# Nama Dokumen: Rukun_iman.txt
# Skor Jaccard Similarity: 0.002403846153846154
# Posisi Index untuk Kata dalam Query: [66, 109, 874, 1121]
#
# Rank: 84
# Nama Dokumen: Munafik.txt
# Skor Jaccard Similarity: 0.00234192037470726
# Posisi Index untuk Kata dalam Query: [307, 403, 514, 523, 529, 534, 543, 660]
#
# Rank: 85
# Nama Dokumen: Akhirat.txt
# Skor Jaccard Similarity: 0.002331002331002331
# Posisi Index untuk Kata dalam Query: [373]
#
# Rank: 86
# Nama Dokumen: Surah_Ali_Imran.txt
# Skor Jaccard Similarity: 0.002325581395348837
# Posisi Index untuk Kata dalam Query: [141, 258, 361, 379]
#
# Rank: 87
# Nama Dokumen: Al-Mustanshir_II.txt
# Skor Jaccard Similarity: 0.0022675736961451248
# Posisi Index untuk Kata dalam Query: [188, 495]
#
# Rank: 88
# Nama Dokumen: Surah_Ar-Rum.txt
# Skor Jaccard Similarity: 0.0022471910112359553
# Posisi Index untuk Kata dalam Query: [90]
#
# Rank: 89
# Nama Dokumen: Surah_Al-Fatihah.txt
# Skor Jaccard Similarity: 0.0022172949002217295
# Posisi Index untuk Kata dalam Query: [496, 535, 751, 892]
#
# Rank: 90
# Nama Dokumen: Zulkifli.txt
# Skor Jaccard Similarity: 0.0022172949002217295
# Posisi Index untuk Kata dalam Query: [1051, 1073]
#
# Rank: 91
# Nama Dokumen: Ibnu_Taimiyah.txt
# Skor Jaccard Similarity: 0.0021413276231263384
# Posisi Index untuk Kata dalam Query: [76]
#
# Rank: 92
# Nama Dokumen: Salat_jenazah.txt
# Skor Jaccard Similarity: 0.002127659574468085
# Posisi Index untuk Kata dalam Query: [43, 168, 363, 929, 968, 1006]
#
# Rank: 93
# Nama Dokumen: Pertempuran_Uhud.txt
# Skor Jaccard Similarity: 0.00211864406779661
# Posisi Index untuk Kata dalam Query: [86, 809, 842, 896]
#
# Rank: 94
# Nama Dokumen: Abdul_Muthalib.txt
# ...
# Posisi Index untuk Kata dalam Query: [293]
#
# Rank: 131
# Nama Dokumen: Ilyas.txt
# Skor Jaccard Similarity: 0.0015503875968992248
# Posisi Index untuk Kata dalam Query: [922, 1038, 1047, 1065, 1069, 1635]
#
# Rank: 132
# Nama Dokumen: Surah_Al-Baqarah.txt
# Skor Jaccard Similarity: 0.0015082956259426848
# Posisi Index untuk Kata dalam Query: [155, 207, 486, 730, 954, 965, 988, 1213]
#
# Rank: 133
# Nama Dokumen: Surah_At-Taubah.txt
# Skor Jaccard Similarity: 0.0015082956259426848
# Posisi Index untuk Kata dalam Query: [108, 850, 993, 1083, 1145, 1204, 1333, 1451]
#
# Rank: 134
# Nama Dokumen: Syirik.txt
# Skor Jaccard Similarity: 0.0014771048744460858
# Posisi Index untuk Kata dalam Query: [424, 1381, 1389, 1415, 1449, 1507, 1577, 1622, 1657, 1682, 1701, 1711]
#
# Rank: 135
# Nama Dokumen: Lut.txt
# Skor Jaccard Similarity: 0.0014285714285714286
# Posisi Index untuk Kata dalam Query: [1860, 2129]
#
# Rank: 136
# Nama Dokumen: Madinah.txt
# Skor Jaccard Similarity: 0.0014124293785310734
# Posisi Index untuk Kata dalam Query: [85, 100, 149, 272, 291, 393, 397, 408, 530, 552, 605, 1122]
#
# Rank: 137
# Nama Dokumen: Ahmad_bin_Hanbal.txt
# Skor Jaccard Similarity: 0.0014084507042253522
# Posisi Index untuk Kata dalam Query: [187, 1006, 1392, 1791]
#
# Rank: 138
# Nama Dokumen: Yahya.txt
# Skor Jaccard Similarity: 0.001402524544179523
# Posisi Index untuk Kata dalam Query: [1531, 2036]
#
# Rank: 139
# Nama Dokumen: Salat_lima_waktu.txt
# Skor Jaccard Similarity: 0.001388888888888889
# Posisi Index untuk Kata dalam Query: [843, 1083, 1917]
#
# Rank: 140
# Nama Dokumen: Hawa.txt
# Skor Jaccard Similarity: 0.0013850415512465374
# Posisi Index untuk Kata dalam Query: [1874]
#
# Rank: 141
# Nama Dokumen: Sara.txt
# Skor Jaccard Similarity: 0.0013774104683195593
# Posisi Index untuk Kata dalam Query: [1640, 2097]
#
# Rank: 142
# Nama Dokumen: Surah_An-Nisa_E2_80_99.txt
# Skor Jaccard Similarity: 0.0013623978201634877
# Posisi Index untuk Kata dalam Query: [64, 75, 1322, 1410, 1429, 1799]
#
# Rank: 143
# Nama Dokumen: Kekhalifahan_Umayyah#Daftar_Khalifah.txt
# Skor Jaccard Similarity: 0.001336898395721925
# Posisi Index untuk Kata dalam Query: [143, 1378, 1447, 2163, 2190, 2210, 2227]
#
# Rank: 144
# Nama Dokumen: Pengepungan_rumah_Utsman.txt
# Skor Jaccard Similarity: 0.0013020833333333333
# Posisi Index untuk Kata dalam Query: [234, 403, 435, 452, 466, 478, 481, 525, 748, 752, 793, 842, 857, 861, 928, 1041, 1132, 1262, 1276, 1283, 1295, 1394, 1670]
#
# Rank: 145
# Nama Dokumen: Ayub_(tokoh_Al-Qur_an).txt
# Skor Jaccard Similarity: 0.0012987012987012987
# Posisi Index untuk Kata dalam Query: [1398, 2120]
#
# Rank: 146
# Nama Dokumen: Kafir.txt
# Skor Jaccard Similarity: 0.0012987012987012987
# Posisi Index untuk Kata dalam Query: [30, 53, 74, 100, 128, 346, 384, 408, 984, 1032, 1105]
#
# Rank: 147
# Nama Dokumen: Yakub_(tokoh_Al-Qur_an).txt
# Skor Jaccard Similarity: 0.0012953367875647669
# Posisi Index untuk Kata dalam Query: [2332, 2725]
#
# Rank: 148
# Nama Dokumen: Maryam.txt
# Skor Jaccard Similarity: 0.0012853470437017994
# Posisi Index untuk Kata dalam Query: [1746, 2048, 2160, 2313]
#
# Rank: 149
# Nama Dokumen: Sulaiman.txt
# Skor Jaccard Similarity: 0.0012853470437017994
# Posisi Index untuk Kata dalam Query: [2440]
#
# Rank: 150
# Nama Dokumen: Yazid_bin_Muawiyah.txt
# Skor Jaccard Similarity: 0.001277139208173691
# Posisi Index untuk Kata dalam Query: [101, 1670, 1873]
#
# Rank: 151
# Nama Dokumen: Ali_bin_Abi_Thalib.txt
# Skor Jaccard Similarity: 0.0012594458438287153
# Posisi Index untuk Kata dalam Query: [67, 72, 79, 101, 115, 122, 156, 242, 257, 287, 355, 367, 383, 392, 399, 418, 438, 444, 449, 476, 496, 510, 544, 550, 555, 595, 643, 658, 684, 711, 801, 873, 879, 898, 913, 951, 1010, 1029, 1032, 1049, 1246, 1273, 1554, 1592, 1674, 1809, 1846, 1861, 1873, 1969, 1993, 2020]
#
# Rank: 152
# Nama Dokumen: Ismail.txt
# Skor Jaccard Similarity: 0.0012594458438287153
# Posisi Index untuk Kata dalam Query: [57, 87, 1591, 2097, 2342, 2520, 2597, 2603, 2617]
#
# Rank: 153
# Nama Dokumen: Makkah.txt
# Skor Jaccard Similarity: 0.0012594458438287153
# Posisi Index untuk Kata dalam Query: [105, 127, 1070, 1101, 1326, 1679]
#
# Rank: 154
# Nama Dokumen: Abdullah_bin_Zubair.txt
# Skor Jaccard Similarity: 0.0012285012285012285
# Posisi Index untuk Kata dalam Query: [60, 315, 395, 436, 456, 485, 914, 1378, 1398, 1433, 1704, 1731, 2371, 2396, 2597]
#
# Rank: 155
# Nama Dokumen: Zul_Qarnain.txt
# Skor Jaccard Similarity: 0.001182033096926714
# Posisi Index untuk Kata dalam Query: [139, 303, 1659, 1668, 1673]
#
# Rank: 156
# Nama Dokumen: Daud_dalam_Islam.txt
# Skor Jaccard Similarity: 0.0011655011655011655
# Posisi Index untuk Kata dalam Query: [2011, 2256]
#
# Rank: 157
# Nama Dokumen: Allah.txt
# Skor Jaccard Similarity: 0.0011337868480725624
# Posisi Index untuk Kata dalam Query: [89, 102, 446, 505, 522, 751]
#
# Rank: 158
# Nama Dokumen: Sahabat_Nabi.txt
# Skor Jaccard Similarity: 0.0011173184357541898
# Posisi Index untuk Kata dalam Query: [63, 77, 95, 118, 150, 199, 291, 444, 513, 556, 734, 767, 890, 1163, 1885, 1889, 2233, 2273, 2280, 2296]
#
# Rank: 159
# Nama Dokumen: Pertempuran_Jamal.txt
# Skor Jaccard Similarity: 0.0011148272017837235
# Posisi Index untuk Kata dalam Query: [53, 57, 65, 71, 80, 103, 140, 164, 179, 202, 210, 270, 275, 284, 299, 303, 314, 344, 350, 374, 375, 392, 404, 409, 416, 424, 492, 520, 527, 540, 547, 556, 618, 668, 699, 793, 1023, 1060, 1224, 1551, 1622, 1739, 1960, 1966, 2374]
#
# Rank: 160
# Nama Dokumen: Yazid_bin_Abdul-Malik.txt
# Skor Jaccard Similarity: 0.0011074197120708748
# Posisi Index untuk Kata dalam Query: [976, 1051, 1099, 1145, 1518]
#
# Rank: 161
# Nama Dokumen: Harun_(tokoh_Al-Qur_an).txt
# Skor Jaccard Similarity: 0.0011049723756906078
# Posisi Index untuk Kata dalam Query: [2788, 2993]
#
# Rank: 162
# Nama Dokumen: Malaikat.txt
# Skor Jaccard Similarity: 0.0010940919037199124
# Posisi Index untuk Kata dalam Query: [355, 416, 646, 818]
#
# Rank: 163
# Nama Dokumen: Nuh_(tokoh_Alkitab).txt
# Skor Jaccard Similarity: 0.0010940919037199124
# Posisi Index untuk Kata dalam Query: [2437]
#
# Rank: 164
# Nama Dokumen: Wabah_Amwas.txt
# Skor Jaccard Similarity: 0.0010672358591248667
# Posisi Index untuk Kata dalam Query: [781, 855, 2400]
#
# Rank: 165
# Nama Dokumen: Perang_Saudara_Islam_I.txt
# Skor Jaccard Similarity: 0.0010626992561105207
# Posisi Index untuk Kata dalam Query: [233, 361, 528, 552, 1610, 1637, 1837, 1869, 1974]
#
# Rank: 166
# Nama Dokumen: Salat.txt
# Skor Jaccard Similarity: 0.0010626992561105207
# Posisi Index untuk Kata dalam Query: [76, 113, 632, 654, 677, 727, 763, 771, 921, 929, 957, 969, 1099, 1121, 1290, 1620, 1624, 2076, 2311, 2327, 2428, 3195, 3294]
#
# Rank: 167
# Nama Dokumen: Syiah.txt
# Skor Jaccard Similarity: 0.0010582010582010583
# Posisi Index untuk Kata dalam Query: [74, 94, 113, 129, 136, 140, 327, 354, 366, 384, 414, 424, 440, 543, 569, 875, 881, 885, 909, 915, 917, 922, 936, 941, 1026, 1082, 1088, 1093, 1451, 2108, 2189]
#
# Rank: 168
# Nama Dokumen: Zakat.txt
# Skor Jaccard Similarity: 0.0010559662090813093
# Posisi Index untuk Kata dalam Query: [256, 687, 832, 939, 1274, 1867]
#
# Rank: 169
# Nama Dokumen: Neraka.txt
# Skor Jaccard Similarity: 0.001017293997965412
# Posisi Index untuk Kata dalam Query: [71, 496, 650]
#
# Rank: 170
# Nama Dokumen: Pertempuran_Badar.txt
# Skor Jaccard Similarity: 0.001006036217303823
# Posisi Index untuk Kata dalam Query: [109, 130, 196, 241, 287, 302, 313, 397, 404, 460, 504, 521, 528, 546, 555, 696, 804, 841, 861, 912, 928, 968, 978, 1018, 1101, 1201, 1301, 1358, 1452, 1480, 1517, 1543, 1841, 2003, 2096, 2372, 2390, 2428, 2463, 2600, 2617, 2665, 2697, 2712, 2748, 2795, 3182, 3380]
#
# Rank: 171
# Nama Dokumen: Al-Qur_27an.txt
# Skor Jaccard Similarity: 0.0009813542688910696
# Posisi Index untuk Kata dalam Query: [90, 113, 150, 167, 199, 345, 766, 775, 849, 1000, 1059, 1091, 1110, 1119, 1290, 1784, 2106, 2183, 2260, 2274, 2636, 2749]
#
# Rank: 172
# Nama Dokumen: Adam.txt
# Skor Jaccard Similarity: 0.000980392156862745
# Posisi Index untuk Kata dalam Query: [3349, 3434]
#
# Rank: 173
# Nama Dokumen: Masa_pemerintahan_Ali.txt
# Skor Jaccard Similarity: 0.0009225092250922509
# Posisi Index untuk Kata dalam Query: [62, 206, 692, 1259, 1298, 1343, 1472, 1495, 1510, 1642, 1759, 1763, 1786, 1827, 1899, 2042, 2073, 2197, 2405]
#
# Rank: 174
# Nama Dokumen: Umar_bin_Abdul_Aziz.txt
# Skor Jaccard Similarity: 0.0009165902841429881
# Posisi Index untuk Kata dalam Query: [626, 686, 1819, 1921, 1996, 2041, 2141, 2582]
#
# Rank: 175
# Nama Dokumen: Ibnu_Sina.txt
# Skor Jaccard Similarity: 0.0008968609865470852
# Posisi Index untuk Kata dalam Query: [399]
#
# Rank: 176
# Nama Dokumen: Utsman_bin_Affan.txt
# Skor Jaccard Similarity: 0.0008865248226950354
# Posisi Index untuk Kata dalam Query: [120, 124, 334, 353, 394, 607, 618, 639, 652, 682, 725, 755, 1601, 1988, 2085, 2092, 2190, 2264, 3077, 3205, 3222, 3406]
#
# Rank: 177
# Nama Dokumen: Abdul_Malik_bin_Marwan.txt
# Skor Jaccard Similarity: 0.0008496176720475786
# Posisi Index untuk Kata dalam Query: [547, 1193, 1855, 2090, 2120, 3170, 3775]
#
# Rank: 178
# Nama Dokumen: Nabi_dan_rasul_dalam_Islam#Daftar_nabi_dan_rasul.txt
# Skor Jaccard Similarity: 0.000846740050804403
# Posisi Index untuk Kata dalam Query: [90, 112, 115, 132, 543, 617, 641, 671, 877, 1043, 1619, 3503, 3685]
#
# Rank: 179
# Nama Dokumen: Marwan_bin_al-Hakam.txt
# Skor Jaccard Similarity: 0.000819672131147541
# Posisi Index untuk Kata dalam Query: [297, 400, 411, 866, 1303, 1322, 2724, 3030, 3247, 3345, 3555, 4122]
#
# Rank: 180
# Nama Dokumen: Yusuf_dalam_Islam.txt
# Skor Jaccard Similarity: 0.000819672131147541
# Posisi Index untuk Kata dalam Query: [1041, 2169, 4438, 5188]
#
# Rank: 181
# Nama Dokumen: Abu_Bakar_ash-Shiddiq.txt
# Skor Jaccard Similarity: 0.0007627765064836003
# Posisi Index untuk Kata dalam Query: [123, 239, 848, 867, 927, 1001, 1015, 1021, 1023, 1044, 1056, 1379, 1617, 1644, 1774, 1832, 1845, 1900, 1912, 1927, 2027, 2063, 2172, 2183, 2760, 3035, 3182, 3253, 3366, 3470, 3498, 3553, 3575, 3612, 3664, 3798, 3847, 3909, 4007, 4057, 4097, 4189]
#
# Rank: 182
# Nama Dokumen: Yunus.txt
# Skor Jaccard Similarity: 0.0007593014426727411
# Posisi Index untuk Kata dalam Query: [2301, 2308, 2319, 2358, 2367, 2389, 2393, 2410, 2415]
#
# Rank: 183
# Nama Dokumen: Sufisme.txt
# Skor Jaccard Similarity: 0.0007518796992481203
# Posisi Index untuk Kata dalam Query: [322, 454, 483, 567, 599, 610, 752, 766, 830, 1420, 1512, 2194, 2615, 2646, 2665]
#
# Rank: 184
# Nama Dokumen: Ibrahim.txt
# Skor Jaccard Similarity: 0.0007485029940119761
# Posisi Index untuk Kata dalam Query: [135, 261, 3278, 3574, 3642, 3654, 3684, 3690, 4308, 4872, 4955, 4983, 4989, 5003]
#
# Rank: 185
# Nama Dokumen: Khalifah#Daftar_Khalifah.txt
# Skor Jaccard Similarity: 0.0006365372374283895
# Posisi Index untuk Kata dalam Query: [37, 129, 142, 660, 813, 857, 867, 891, 1515, 1625, 2144, 2840, 2851, 2967, 3802, 3819, 3828, 3883, 3925, 3953, 4002, 4020, 4032, 4285, 4539, 4552, 4687, 4724, 4876, 4909, 4924, 4941, 5342]
#
# Rank: 186
# Nama Dokumen: Islam.txt
# Skor Jaccard Similarity: 0.000630119722747322
# Posisi Index untuk Kata dalam Query: [91, 358, 423, 506, 1059, 1118, 1131, 1535, 1692, 1695, 1701, 1738, 1758, 1773, 1799, 1808, 1828, 1848, 1870, 1875, 1906, 1911, 1919, 1948, 1967, 2042, 2098, 2120, 2139, 2179, 2199, 2204, 2250, 2314, 2416, 2462, 2478, 2557, 2575, 2809, 2847, 2942, 2958, 2961, 3004, 3203, 3210, 3221, 3265, 3283, 3322, 3354, 3427, 3692, 4091, 4143, 4247, 4264, 4329, 4475, 4532]
#
# Rank: 187
# Nama Dokumen: Haji.txt
# Skor Jaccard Similarity: 0.0006218905472636816
# Posisi Index untuk Kata dalam Query: [223, 618, 766, 792, 1065, 1287, 1798, 2297, 2600, 3365, 3703, 3779, 3851, 3934, 4125, 5093]
#
# Rank: 188
# Nama Dokumen: Muhammad.txt
# Skor Jaccard Similarity: 0.0006172839506172839
# Posisi Index untuk Kata dalam Query: [6, 8, 60, 62, 68, 70, 120, 135, 152, 168, 176, 214, 227, 259, 269, 300, 316, 330, 356, 381, 388, 399, 400, 434, 447, 521, 530, 547, 549, 620, 635, 747, 749, 751, 759, 767, 773, 808, 812, 836, 857, 863, 897, 907, 918, 932, 978, 1008, 1072, 1080, 1090, 1099, 1103, 1142, 1162, 1164, 1185, 1214, 1285, 1288, 1343, 1367, 1370, 1385, 1425, 1465, 1489, 1514, 1546, 1602, 1669, 1684, 1717, 1744, 1749, 1771, 1806, 1827, 1861, 1881, 1929, 1972, 1992, 2024, 2062, 2077, 2097, 2110, 2140, 2174, 2222, 2239, 2275, 2314, 2335, 2361, 2365, 2381, 2398, 2428, 2440, 2450, 2454, 2459, 2480, 2501, 2514, 2549, 2574, 2591, 2699, 2715, 2928, 2936, 2953, 2972, 2975, 3044, 3048, 3063, 3126, 3139, 3162, 3183, 3226, 3243, 3312, 3322, 3329, 3412, 3427, 3476, 3480, 3490, 3509, 3525, 3548, 3554, 3563, 3585, 3610, 3623, 3659, 3695, 3698, 3709, 3735, 3746, 3770, 3791, 3857, 3877, 3883, 3898, 3911, 3929, 3934, 3958, 3964, 3982, 3993, 3998, 4029, 4050, 4122, 4158, 4192, 4260, 4285, 4305, 4308, 4319, 4339, 4380, 4390, 4431, 4451, 4476, 4527, 4581, 4598, 4640, 4691, 4699, 4712, 4740, 4756, 4775, 4794, 4799, 4839, 4849, 4868, 4870, 4877, 4911, 4918, 4941, 4971, 4975, 5000, 5014, 5034]
#
# Rank: 189
# Nama Dokumen: Muhammad_bin_Abdul_Wahhab.txt
# Skor Jaccard Similarity: 0.0006108735491753207
# Posisi Index untuk Kata dalam Query: [6, 11, 78, 327, 387, 395, 405, 413, 476, 482, 518, 545, 552, 628, 672, 689, 714, 738, 772, 796, 852, 875, 892, 952, 977, 1016, 1028, 1038, 1065, 1096, 1120, 1141, 1209, 1245, 1250, 1358, 1408, 1435, 1445, 1513, 1585, 1598, 1638, 1665, 1685, 1703, 1715, 1724, 1789, 1825, 1837, 1843, 1860, 1871, 1889, 1942, 1959, 1964, 1981, 2091, 2093, 2108, 2113, 2118, 2283, 2653, 2685, 2759, 2783, 2806, 2837, 2841, 2952, 3059, 3092, 3153, 3189, 3227, 3245, 3262, 3275, 3291, 3333, 3381, 3388, 3400, 3583, 3870, 3875, 3885, 3992, 4247, 4405, 4428, 4720, 4783, 4825, 4849, 4886, 4933, 4967, 4990, 5160, 5202, 5264, 5281, 5429, 5549, 5624, 5638]
#
# Rank: 190
# Nama Dokumen: Umar_bin_Khattab.txt
# Skor Jaccard Similarity: 0.0005903187721369539
# Posisi Index untuk Kata dalam Query: [72, 77, 142, 386, 398, 413, 425, 435, 452, 472, 477, 499, 518, 543, 587, 701, 715, 736, 881, 933, 944, 1003, 1016, 1019, 1045, 1073, 1080, 1126, 1138, 1143, 1148, 1166, 1208, 1210, 1229, 1265, 1272, 1297, 1304, 1309, 1765, 2260, 2284, 2646, 2658, 3142, 3828, 4411, 4414, 4917, 5325, 5521, 5529, 5731, 5763, 5805, 5869, 5956, 5960, 5988, 6088, 6179, 6369]
#
# Rank: 191
# Nama Dokumen: Kekhalifahan_Abbasiyah#Kekhalifahan_Abbasiyah_di_Kairo.txt
# Skor Jaccard Similarity: 0.0005599104143337066
# Posisi Index untuk Kata dalam Query: [77, 435, 637, 722, 1135, 2521, 4767, 6526, 7108, 7375, 7414, 7425]
#
# Rank: 192
# Nama Dokumen: Muawiyah_bin_Abu_Sufyan.txt
# Skor Jaccard Similarity: 0.0005546311702717693
# Posisi Index untuk Kata dalam Query: [53, 366, 385, 390, 468, 705, 711, 1775, 1946, 2097, 3421, 3734, 3740, 5445, 5752, 5773, 5786, 5891]
#
# Rank: 193
# Nama Dokumen: Musa.txt
# Skor Jaccard Similarity: 0.0005353319057815846
# Posisi Index untuk Kata dalam Query: [4539, 6707, 6743, 6793, 6855, 7564]
#
# Rank: 194
# Nama Dokumen: Isa.txt
# Skor Jaccard Similarity: 0.0005347593582887701
# Posisi Index untuk Kata dalam Query: [96, 4240, 4325, 4349, 4582, 4784, 5510, 5755, 6201]
#
# Rank: 195
# Nama Dokumen: Sunni.txt
# Skor Jaccard Similarity: 0.0005230125523012552
# Posisi Index untuk Kata dalam Query: [41, 51, 60, 79, 400, 487, 947, 966, 974, 984, 1309, 1475, 1485, 1497, 1537, 1627, 1699, 1722, 1854, 2036, 2205, 2210, 2230, 2538, 3086, 3274, 3448, 4078, 4087, 4279, 4284, 4305, 4321, 4400, 4424, 5308, 5333]
#
# Rank: 196
# Nama Dokumen: Kekhalifahan_Rasyidin.txt
# Skor Jaccard Similarity: 0.000510986203372509
# Posisi Index untuk Kata dalam Query: [26, 51, 187, 350, 375, 488, 493, 505, 511, 546, 581, 600, 631, 712, 733, 792, 930, 950, 952, 993, 1012, 1060, 1079, 1105, 1110, 1135, 1138, 1357, 1371, 1773, 1785, 1863, 1900, 1952, 2419, 2909, 2956, 3051, 3677, 4125, 4233, 4542, 5652, 6300, 6383, 6434, 6601, 6623, 6704, 6708, 6722, 6937, 7493, 7801, 7857, 8253, 8271, 8450, 8473, 8520, 8573, 8609, 8639, 8700]
#
# Rank: 197
# Nama Dokumen: Khalid_bin_Walid.txt
# Skor Jaccard Similarity: 0.0004338394793926247
# Posisi Index untuk Kata dalam Query: [46, 94, 118, 156, 346, 412, 487, 541, 564, 585, 592, 609, 618, 673, 790, 795, 817, 834, 853, 873, 951, 1015, 1068, 1115, 1259, 1273, 1309, 1318, 1341, 1387, 1403, 1415, 1435, 1444, 1527, 1603, 1609, 1896, 1908, 2192, 2197, 2203, 2206, 3423, 3914, 4887, 6156, 6744, 6794, 6850, 6993, 7035, 7403, 8768, 8851, 9116]
#
# Nama dokumen telah disimpan dalam file: document_names.txt
