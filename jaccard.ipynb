# %%
import json
import time

class JaccardSimilarity:
    def __init__(self, tokenized_documents):
        self.documents = [set(doc) for doc in tokenized_documents]

    def _calculate_jaccard_similarity(self, query_terms, doc_terms):
        intersection = len(query_terms.intersection(doc_terms))
        union = len(query_terms.union(doc_terms))
        return intersection / union if union != 0 else 0

    def search(self, query):
        query_terms = set(query.split())
        relevant_documents = []

        for doc_index, doc_terms in enumerate(self.documents):
            similarity = self._calculate_jaccard_similarity(query_terms, doc_terms)
            if similarity > 0:
                relevant_documents.append((doc_index, similarity))

        relevant_documents.sort(key=lambda x: x[1], reverse=True)
        return relevant_documents


if __name__ == "__main__":
    # Load tokenized documents from file
    with open('tokenized_documents.txt', 'r', encoding='utf-8') as f:
        tokenized_documents = [set(line.strip().split()) for line in f.readlines()]

    # Create a JaccardSimilarity instance
    jaccard_similarity = JaccardSimilarity(tokenized_documents)

    # Load document names
    with open('document_names.txt', 'r', encoding='utf-8') as f:
        document_names = [line.strip() for line in f.readlines()]

    # Load the URL to document info dictionary from the JSON file
    with open('urltodoc.json', 'r', encoding='utf-8') as f:
        url_to_document = json.load(f)

    # Input query
    query = input("Masukkan query: ")

    start_time = time.time()
    # Search using Jaccard similarity
    search_results = jaccard_similarity.search(query)

    # Display search results
    print("\nHasil Pencarian:")
    n=0
    for rank, (doc_index, similarity) in enumerate(search_results, start=1):
        if similarity == 0:
            continue
        document_name = document_names[doc_index]
        document_url = url_to_document.get(document_name, "N/A")
        print(f"Rank: {rank}")
        print(f"Nama Dokumen: {document_name}")
        print(f"Similaritas Jaccard: {similarity:.4f}")
        print(f"Document URL: '{document_url}\n")
        n+=1

    end_time = time.time()
    print(f"Waktu eksekusi: {end_time - start_time:.9f} detik")
    print(f"Jumlah dokumen: {n}")
# Out:
# Hasil Pencarian:
# Rank: 1
# Nama Dokumen: Khalid_bin_Sa_id.txt
# Similaritas Jaccard: 0.0147
# Document URL: 'https://id.wikipedia.org/wiki/Khalid_bin_Sa%27id
#
# Rank: 2
# Nama Dokumen: Al-Mutawakkil_I.txt
# Similaritas Jaccard: 0.0135
# Document URL: 'https://id.wikipedia.org/wiki/Al-Mutawakkil_I
#
# Rank: 3
# Nama Dokumen: Ibnu_Yunus.txt
# Similaritas Jaccard: 0.0122
# Document URL: 'https://id.wikipedia.org/wiki/Ibnu_Yunus
#
# Rank: 4
# Nama Dokumen: Bani_Taim.txt
# Similaritas Jaccard: 0.0104
# Document URL: 'https://id.wikipedia.org/wiki/Bani_Taim
#
# Rank: 5
# Nama Dokumen: Yazid_bin_Walid.txt
# Similaritas Jaccard: 0.0087
# Document URL: 'https://id.wikipedia.org/wiki/Yazid_bin_Walid
#
# Rank: 6
# Nama Dokumen: Pertempuran_Yamamah.txt
# Similaritas Jaccard: 0.0085
# Document URL: 'https://id.wikipedia.org/wiki/Pertempuran_Yamamah
#
# Rank: 7
# Nama Dokumen: Al-Humaidi.txt
# Similaritas Jaccard: 0.0085
# Document URL: 'https://id.wikipedia.org/wiki/Al-Humaidi
#
# Rank: 8
# Nama Dokumen: Pengepungan_Tha_if.txt
# Similaritas Jaccard: 0.0083
# Document URL: 'https://id.wikipedia.org/wiki/Pengepungan_Tha%27if
#
# Rank: 9
# Nama Dokumen: Al-Hakim_II.txt
# Similaritas Jaccard: 0.0080
# Document URL: 'https://id.wikipedia.org/wiki/Al-Hakim_II
#
# Rank: 10
# Nama Dokumen: Ekspedisi_Tabuk.txt
# Similaritas Jaccard: 0.0074
# Document URL: 'https://id.wikipedia.org/wiki/Ekspedisi_Tabuk
#
# Rank: 11
# Nama Dokumen: Salat_Taubat.txt
# Similaritas Jaccard: 0.0072
# Document URL: 'https://id.wikipedia.org/wiki/Salat_Taubat
#
# Rank: 12
# Nama Dokumen: Abdullah_bin_Abdul_Muthalib.txt
# Similaritas Jaccard: 0.0070
# Document URL: 'https://id.wikipedia.org/wiki/Abdullah_bin_Abdul_Muthalib
#
# Rank: 13
# Nama Dokumen: Marwan_bin_Muhammad.txt
# Similaritas Jaccard: 0.0068
# Document URL: 'https://id.wikipedia.org/wiki/Marwan_bin_Muhammad
#
# Rank: 14
# Nama Dokumen: Surah_Al-A_E2_80_99la.txt
# Similaritas Jaccard: 0.0067
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Al-A%E2%80%99la
#
# Rank: 15
# Nama Dokumen: Haram.txt
# Similaritas Jaccard: 0.0065
# Document URL: 'https://id.wikipedia.org/wiki/Haram
#
# Rank: 16
# Nama Dokumen: Al-Qurthubi.txt
# Similaritas Jaccard: 0.0062
# Document URL: 'https://id.wikipedia.org/wiki/Al-Qurthubi
#
# Rank: 17
# Nama Dokumen: Al-Barbahari.txt
# Similaritas Jaccard: 0.0062
# Document URL: 'https://id.wikipedia.org/wiki/Al-Barbahari
#
# Rank: 18
# Nama Dokumen: Ibnu_Khuzaimah.txt
# Similaritas Jaccard: 0.0058
# Document URL: 'https://id.wikipedia.org/wiki/Ibnu_Khuzaimah
#
# Rank: 19
# Nama Dokumen: Salat_Rawatib.txt
# Similaritas Jaccard: 0.0058
# Document URL: 'https://id.wikipedia.org/wiki/Salat_Rawatib
#
# Rank: 20
# Nama Dokumen: Hakim_an-Naisaburi.txt
# Similaritas Jaccard: 0.0058
# Document URL: 'https://id.wikipedia.org/wiki/Hakim_an-Naisaburi
#
# Rank: 21
# Nama Dokumen: Al-Walid_bin_Yazid.txt
# Similaritas Jaccard: 0.0058
# Document URL: 'https://id.wikipedia.org/wiki/Al-Walid_bin_Yazid
#
# Rank: 22
# Nama Dokumen: Al-Biruni.txt
# Similaritas Jaccard: 0.0053
# Document URL: 'https://id.wikipedia.org/wiki/Al-Biruni
#
# Rank: 23
# Nama Dokumen: Hijrah_ke_Abisinia.txt
# Similaritas Jaccard: 0.0053
# Document URL: 'https://id.wikipedia.org/wiki/Hijrah_ke_Abisinia
#
# Rank: 24
# Nama Dokumen: Perjanjian_Hudaibiyyah.txt
# Similaritas Jaccard: 0.0050
# Document URL: 'https://id.wikipedia.org/wiki/Perjanjian_Hudaibiyyah
#
# Rank: 25
# Nama Dokumen: Luqman_al-Hakim.txt
# Similaritas Jaccard: 0.0048
# Document URL: 'https://id.wikipedia.org/wiki/Luqman_al-Hakim
#
# Rank: 26
# Nama Dokumen: Salat_Tasbih.txt
# Similaritas Jaccard: 0.0047
# Document URL: 'https://id.wikipedia.org/wiki/Salat_Tasbih
#
# Rank: 27
# Nama Dokumen: Ushul_Fikih.txt
# Similaritas Jaccard: 0.0047
# Document URL: 'https://id.wikipedia.org/wiki/Ushul_Fikih
#
# Rank: 28
# Nama Dokumen: Yokhebed.txt
# Similaritas Jaccard: 0.0046
# Document URL: 'https://id.wikipedia.org/wiki/Yokhebed
#
# Rank: 29
# Nama Dokumen: Muawiyah_bin_Yazid.txt
# Similaritas Jaccard: 0.0044
# Document URL: 'https://id.wikipedia.org/wiki/Muawiyah_bin_Yazid
#
# Rank: 30
# Nama Dokumen: Ibnu_Hazm.txt
# Similaritas Jaccard: 0.0044
# Document URL: 'https://id.wikipedia.org/wiki/Ibnu_Hazm
#
# Rank: 31
# Nama Dokumen: Salat_Tahajud.txt
# Similaritas Jaccard: 0.0042
# Document URL: 'https://id.wikipedia.org/wiki/Salat_Tahajud
#
# Rank: 32
# Nama Dokumen: Pertempuran_Hunain.txt
# Similaritas Jaccard: 0.0041
# Document URL: 'https://id.wikipedia.org/wiki/Pertempuran_Hunain
#
# Rank: 33
# Nama Dokumen: Surah_An-N_C4_81s.txt
# Similaritas Jaccard: 0.0041
# Document URL: 'https://id.wikipedia.org/wiki/Surah_An-N%C4%81s
#
# Rank: 34
# Nama Dokumen: Surah_Ar-Ra_E2_80_99d.txt
# Similaritas Jaccard: 0.0040
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Ar-Ra%E2%80%99d
#
# Rank: 35
# Nama Dokumen: Surah_Al-Anfal.txt
# Similaritas Jaccard: 0.0040
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Al-Anfal
#
# Rank: 36
# Nama Dokumen: Iman.txt
# Similaritas Jaccard: 0.0038
# Document URL: 'https://id.wikipedia.org/wiki/Iman
#
# Rank: 37
# Nama Dokumen: Surah_Luqman.txt
# Similaritas Jaccard: 0.0037
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Luqman
#
# Rank: 38
# Nama Dokumen: Surah_Al-An_27am.txt
# Similaritas Jaccard: 0.0036
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Al-An%27am
#
# Rank: 39
# Nama Dokumen: Salat_Hajat.txt
# Similaritas Jaccard: 0.0036
# Document URL: 'https://id.wikipedia.org/wiki/Salat_Hajat
#
# Rank: 40
# Nama Dokumen: Al-Mustamsik.txt
# Similaritas Jaccard: 0.0035
# Document URL: 'https://id.wikipedia.org/wiki/Al-Mustamsik
#
# Rank: 41
# Nama Dokumen: Ijmak.txt
# Similaritas Jaccard: 0.0035
# Document URL: 'https://id.wikipedia.org/wiki/Ijmak
#
# Rank: 42
# Nama Dokumen: Surah__27Abasa.txt
# Similaritas Jaccard: 0.0034
# Document URL: 'https://id.wikipedia.org/wiki/Surah_%27Abasa
#
# Rank: 43
# Nama Dokumen: Pembunuhan_Ali.txt
# Similaritas Jaccard: 0.0033
# Document URL: 'https://id.wikipedia.org/wiki/Pembunuhan_Ali
#
# Rank: 44
# Nama Dokumen: Surah_Al-Ikhlas.txt
# Similaritas Jaccard: 0.0033
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Al-Ikhlas
#
# Rank: 45
# Nama Dokumen: Akidah_Islam.txt
# Similaritas Jaccard: 0.0032
# Document URL: 'https://id.wikipedia.org/wiki/Akidah_Islam
#
# Rank: 46
# Nama Dokumen: Zikir.txt
# Similaritas Jaccard: 0.0031
# Document URL: 'https://id.wikipedia.org/wiki/Zikir
#
# Rank: 47
# Nama Dokumen: Surah_Al-Hujurat.txt
# Similaritas Jaccard: 0.0030
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Al-Hujurat
#
# Rank: 48
# Nama Dokumen: Mazhab.txt
# Similaritas Jaccard: 0.0030
# Document URL: 'https://id.wikipedia.org/wiki/Mazhab
#
# Rank: 49
# Nama Dokumen: Syurahbil_bin_Hasanah.txt
# Similaritas Jaccard: 0.0030
# Document URL: 'https://id.wikipedia.org/wiki/Syurahbil_bin_Hasanah
#
# Rank: 50
# Nama Dokumen: Ibnu_al-Haitsam.txt
# Similaritas Jaccard: 0.0029
# Document URL: 'https://id.wikipedia.org/wiki/Ibnu_al-Haitsam
#
# Rank: 51
# Nama Dokumen: Salaf.txt
# Similaritas Jaccard: 0.0028
# Document URL: 'https://id.wikipedia.org/wiki/Salaf
#
# Rank: 52
# Nama Dokumen: Al-Mutawakkil_II.txt
# Similaritas Jaccard: 0.0028
# Document URL: 'https://id.wikipedia.org/wiki/Al-Mutawakkil_II
#
# Rank: 53
# Nama Dokumen: Amr_bin_Ash.txt
# Similaritas Jaccard: 0.0028
# Document URL: 'https://id.wikipedia.org/wiki/Amr_bin_Ash
#
# Rank: 54
# Nama Dokumen: Salat_Duha.txt
# Similaritas Jaccard: 0.0028
# Document URL: 'https://id.wikipedia.org/wiki/Salat_Duha
#
# Rank: 55
# Nama Dokumen: Akhirat.txt
# Similaritas Jaccard: 0.0027
# Document URL: 'https://id.wikipedia.org/wiki/Akhirat
#
# Rank: 56
# Nama Dokumen: Hijrah.txt
# Similaritas Jaccard: 0.0026
# Document URL: 'https://id.wikipedia.org/wiki/Hijrah
#
# Rank: 57
# Nama Dokumen: Syits.txt
# Similaritas Jaccard: 0.0025
# Document URL: 'https://id.wikipedia.org/wiki/Syits
#
# Rank: 58
# Nama Dokumen: Surah_Al-Fatihah.txt
# Similaritas Jaccard: 0.0025
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Al-Fatihah
#
# Rank: 59
# Nama Dokumen: Rukun_iman.txt
# Similaritas Jaccard: 0.0025
# Document URL: 'https://id.wikipedia.org/wiki/Rukun_iman
#
# Rank: 60
# Nama Dokumen: Surah_Ali_Imran.txt
# Similaritas Jaccard: 0.0024
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Ali_Imran
#
# Rank: 61
# Nama Dokumen: Zulkifli.txt
# Similaritas Jaccard: 0.0024
# Document URL: 'https://id.wikipedia.org/wiki/Zulkifli
#
# Rank: 62
# Nama Dokumen: Al-Mustanshir_II.txt
# Similaritas Jaccard: 0.0024
# Document URL: 'https://id.wikipedia.org/wiki/Al-Mustanshir_II
#
# Rank: 63
# Nama Dokumen: Salat_jenazah.txt
# Similaritas Jaccard: 0.0023
# Document URL: 'https://id.wikipedia.org/wiki/Salat_jenazah
#
# Rank: 64
# Nama Dokumen: Idris.txt
# Similaritas Jaccard: 0.0023
# Document URL: 'https://id.wikipedia.org/wiki/Idris
#
# Rank: 65
# Nama Dokumen: Abdul_Muthalib.txt
# Similaritas Jaccard: 0.0022
# Document URL: 'https://id.wikipedia.org/wiki/Abdul_Muthalib
#
# Rank: 66
# Nama Dokumen: Ibnu_Taimiyah.txt
# Similaritas Jaccard: 0.0022
# Document URL: 'https://id.wikipedia.org/wiki/Ibnu_Taimiyah
#
# Rank: 67
# Nama Dokumen: Salat_Jumat.txt
# Similaritas Jaccard: 0.0022
# Document URL: 'https://id.wikipedia.org/wiki/Salat_Jumat
#
# Rank: 68
# Nama Dokumen: Pertempuran_Uhud.txt
# Similaritas Jaccard: 0.0022
# Document URL: 'https://id.wikipedia.org/wiki/Pertempuran_Uhud
#
# Rank: 69
# Nama Dokumen: Tauhid.txt
# Similaritas Jaccard: 0.0021
# Document URL: 'https://id.wikipedia.org/wiki/Tauhid
#
# Rank: 70
# Nama Dokumen: Pertempuran_Shiffin.txt
# Similaritas Jaccard: 0.0021
# Document URL: 'https://id.wikipedia.org/wiki/Pertempuran_Shiffin
#
# Rank: 71
# Nama Dokumen: Muhammad_bin_Ismail_al-Bukhari.txt
# Similaritas Jaccard: 0.0021
# Document URL: 'https://id.wikipedia.org/wiki/Muhammad_bin_Ismail_al-Bukhari
#
# Rank: 72
# Nama Dokumen: Zakariyya.txt
# Similaritas Jaccard: 0.0021
# Document URL: 'https://id.wikipedia.org/wiki/Zakariyya
#
# Rank: 73
# Nama Dokumen: Ikrimah_bin_Abu_Jahal.txt
# Similaritas Jaccard: 0.0020
# Document URL: 'https://id.wikipedia.org/wiki/Ikrimah_bin_Abu_Jahal
#
# Rank: 74
# Nama Dokumen: Syuaib.txt
# Similaritas Jaccard: 0.0020
# Document URL: 'https://id.wikipedia.org/wiki/Syuaib
#
# Rank: 75
# Nama Dokumen: Isra_Mikraj.txt
# Similaritas Jaccard: 0.0020
# Document URL: 'https://id.wikipedia.org/wiki/Isra_Mikraj
#
# Rank: 76
# Nama Dokumen: Hud.txt
# Similaritas Jaccard: 0.0020
# Document URL: 'https://id.wikipedia.org/wiki/Hud
#
# Rank: 77
# Nama Dokumen: Syahadat.txt
# Similaritas Jaccard: 0.0019
# Document URL: 'https://id.wikipedia.org/wiki/Syahadat
#
# Rank: 78
# Nama Dokumen: Abu_Lu_u_ah.txt
# Similaritas Jaccard: 0.0019
# Document URL: 'https://id.wikipedia.org/wiki/Abu_Lu%27lu%27ah
#
# Rank: 79
# Nama Dokumen: Fikih.txt
# Similaritas Jaccard: 0.0019
# Document URL: 'https://id.wikipedia.org/wiki/Fikih
#
# Rank: 80
# Nama Dokumen: Saleh.txt
# Similaritas Jaccard: 0.0019
# Document URL: 'https://id.wikipedia.org/wiki/Saleh
#
# Rank: 81
# Nama Dokumen: Ishak_dalam_Islam.txt
# Similaritas Jaccard: 0.0019
# Document URL: 'https://id.wikipedia.org/wiki/Ishak_dalam_Islam
#
# Rank: 82
# Nama Dokumen: Surah_Maryam.txt
# Similaritas Jaccard: 0.0018
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Maryam
#
# Rank: 83
# Nama Dokumen: Kalender_Hijriah.txt
# Similaritas Jaccard: 0.0018
# Document URL: 'https://id.wikipedia.org/wiki/Kalender_Hijriah
#
# Rank: 84
# Nama Dokumen: Ilyasa.txt
# Similaritas Jaccard: 0.0018
# Document URL: 'https://id.wikipedia.org/wiki/Ilyasa
#
# Rank: 85
# Nama Dokumen: Ibnul_Qayyim_al-Jauziyyah.txt
# Similaritas Jaccard: 0.0018
# Document URL: 'https://id.wikipedia.org/wiki/Ibnul_Qayyim_al-Jauziyyah
#
# Rank: 86
# Nama Dokumen: Ka_27bah.txt
# Similaritas Jaccard: 0.0018
# Document URL: 'https://id.wikipedia.org/wiki/Ka%27bah
#
# Rank: 87
# Nama Dokumen: Suku_Quraisy.txt
# Similaritas Jaccard: 0.0017
# Document URL: 'https://id.wikipedia.org/wiki/Suku_Quraisy
#
# Rank: 88
# Nama Dokumen: Ilyas.txt
# Similaritas Jaccard: 0.0017
# Document URL: 'https://id.wikipedia.org/wiki/Ilyas
#
# Rank: 89
# Nama Dokumen: Al-Walid_bin_Abdul-Malik.txt
# Similaritas Jaccard: 0.0017
# Document URL: 'https://id.wikipedia.org/wiki/Al-Walid_bin_Abdul-Malik
#
# Rank: 90
# Nama Dokumen: Surah_Al-Ma_E2_80_99idah.txt
# Similaritas Jaccard: 0.0016
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Al-Ma%E2%80%99idah
#
# Rank: 91
# Nama Dokumen: Rukun_Islam.txt
# Similaritas Jaccard: 0.0016
# Document URL: 'https://id.wikipedia.org/wiki/Rukun_Islam
#
# Rank: 92
# Nama Dokumen: Al-Mustakfi_II.txt
# Similaritas Jaccard: 0.0016
# Document URL: 'https://id.wikipedia.org/wiki/Al-Mustakfi_II
#
# Rank: 93
# Nama Dokumen: Surah_Al-Baqarah.txt
# Similaritas Jaccard: 0.0016
# Document URL: 'https://id.wikipedia.org/wiki/Surah_Al-Baqarah
#
# Rank: 94
# Nama Dokumen: Lut.txt
# Similaritas Jaccard: 0.0015
# Document URL: 'https://id.wikipedia.org/wiki/Lut
#
# Rank: 95
# Nama Dokumen: Surah_At-Taubah.txt
# Similaritas Jaccard: 0.0015
# Document URL: 'https://id.wikipedia.org/wiki/Surah_At-Taubah
#
# Rank: 96
# Nama Dokumen: Syirik.txt
# Similaritas Jaccard: 0.0015
# Document URL: 'https://id.wikipedia.org/wiki/Syirik
#
# Rank: 97
# Nama Dokumen: Yahya.txt
# Similaritas Jaccard: 0.0015
# Document URL: 'https://id.wikipedia.org/wiki/Yahya
#
# Rank: 98
# Nama Dokumen: Maryam.txt
# Similaritas Jaccard: 0.0015
# Document URL: 'https://id.wikipedia.org/wiki/Maryam
#
# Rank: 99
# Nama Dokumen: Ahmad_bin_Hanbal.txt
# Similaritas Jaccard: 0.0014
# Document URL: 'https://id.wikipedia.org/wiki/Ahmad_bin_Hanbal
#
# Rank: 100
# Nama Dokumen: Sara.txt
# Similaritas Jaccard: 0.0014
# Document URL: 'https://id.wikipedia.org/wiki/Sara
#
# Rank: 101
# Nama Dokumen: Salat_lima_waktu.txt
# Similaritas Jaccard: 0.0014
# Document URL: 'https://id.wikipedia.org/wiki/Salat_lima_waktu
#
# Rank: 102
# Nama Dokumen: Ayub_(tokoh_Al-Qur_an).txt
# Similaritas Jaccard: 0.0014
# Document URL: 'https://id.wikipedia.org/wiki/Ayub_(tokoh_Al-Qur%27an)
#
# Rank: 103
# Nama Dokumen: Surah_An-Nisa_E2_80_99.txt
# Similaritas Jaccard: 0.0014
# Document URL: 'https://id.wikipedia.org/wiki/Surah_An-Nisa%E2%80%99
#
# Rank: 104
# Nama Dokumen: Pengepungan_rumah_Utsman.txt
# Similaritas Jaccard: 0.0014
# Document URL: 'https://id.wikipedia.org/wiki/Pengepungan_rumah_Utsman
#
# Rank: 105
# Nama Dokumen: Yakub_(tokoh_Al-Qur_an).txt
# Similaritas Jaccard: 0.0014
# Document URL: 'https://id.wikipedia.org/wiki/Yakub_(tokoh_Al-Qur%27an)
#
# Rank: 106
# Nama Dokumen: Ismail.txt
# Similaritas Jaccard: 0.0014
# Document URL: 'https://id.wikipedia.org/wiki/Ismail
#
# Rank: 107
# Nama Dokumen: Sulaiman.txt
# Similaritas Jaccard: 0.0014
# Document URL: 'https://id.wikipedia.org/wiki/Sulaiman
#
# Rank: 108
# Nama Dokumen: Yazid_bin_Muawiyah.txt
# Similaritas Jaccard: 0.0013
# Document URL: 'https://id.wikipedia.org/wiki/Yazid_bin_Muawiyah
#
# Rank: 109
# Nama Dokumen: Madinah.txt
# Similaritas Jaccard: 0.0013
# Document URL: 'https://id.wikipedia.org/wiki/Madinah
#
# Rank: 110
# Nama Dokumen: Ali_bin_Abi_Thalib.txt
# Similaritas Jaccard: 0.0013
# Document URL: 'https://id.wikipedia.org/wiki/Ali_bin_Abi_Thalib
#
# Rank: 111
# Nama Dokumen: Abdullah_bin_Zubair.txt
# Similaritas Jaccard: 0.0013
# Document URL: 'https://id.wikipedia.org/wiki/Abdullah_bin_Zubair
#
# Rank: 112
# Nama Dokumen: Kekhalifahan_Umayyah#Daftar_Khalifah.txt
# Similaritas Jaccard: 0.0013
# Document URL: 'https://id.wikipedia.org/wiki/Kekhalifahan_Umayyah#Daftar_Khalifah
#
# Rank: 113
# Nama Dokumen: Zul_Qarnain.txt
# Similaritas Jaccard: 0.0013
# Document URL: 'https://id.wikipedia.org/wiki/%C5%BBul_Qarnain
#
# Rank: 114
# Nama Dokumen: Allah.txt
# Similaritas Jaccard: 0.0013
# Document URL: 'https://id.wikipedia.org/wiki/Allah
#
# Rank: 115
# Nama Dokumen: Daud_dalam_Islam.txt
# Similaritas Jaccard: 0.0012
# Document URL: 'https://id.wikipedia.org/wiki/Daud_dalam_Islam
#
# Rank: 116
# Nama Dokumen: Pertempuran_Jamal.txt
# Similaritas Jaccard: 0.0012
# Document URL: 'https://id.wikipedia.org/wiki/Pertempuran_Jamal
#
# Rank: 117
# Nama Dokumen: Harun_(tokoh_Al-Qur_an).txt
# Similaritas Jaccard: 0.0012
# Document URL: 'https://id.wikipedia.org/wiki/Harun_(tokoh_Al-Qur%27an)
#
# Rank: 118
# Nama Dokumen: Sahabat_Nabi.txt
# Similaritas Jaccard: 0.0012
# Document URL: 'https://id.wikipedia.org/wiki/Sahabat_Nabi
#
# Rank: 119
# Nama Dokumen: Makkah.txt
# Similaritas Jaccard: 0.0012
# Document URL: 'https://id.wikipedia.org/wiki/Makkah
#
# Rank: 120
# Nama Dokumen: Nuh_(tokoh_Alkitab).txt
# Similaritas Jaccard: 0.0012
# Document URL: 'https://id.wikipedia.org/wiki/Nuh_(tokoh_Alkitab)
#
# Rank: 121
# Nama Dokumen: Malaikat.txt
# Similaritas Jaccard: 0.0012
# Document URL: 'https://id.wikipedia.org/wiki/Malaikat
#
# Rank: 122
# Nama Dokumen: Perang_Saudara_Islam_I.txt
# Similaritas Jaccard: 0.0012
# Document URL: 'https://id.wikipedia.org/wiki/Perang_Saudara_Islam_I
#
# Rank: 123
# Nama Dokumen: Yazid_bin_Abdul-Malik.txt
# Similaritas Jaccard: 0.0011
# Document URL: 'https://id.wikipedia.org/wiki/Yazid_bin_Abdul-Malik
#
# Rank: 124
# Nama Dokumen: Syiah.txt
# Similaritas Jaccard: 0.0011
# Document URL: 'https://id.wikipedia.org/wiki/Syiah
#
# Rank: 125
# Nama Dokumen: Salat.txt
# Similaritas Jaccard: 0.0011
# Document URL: 'https://id.wikipedia.org/wiki/Salat
#
# Rank: 126
# Nama Dokumen: Masa_pemerintahan_Ali.txt
# Similaritas Jaccard: 0.0011
# Document URL: 'https://id.wikipedia.org/wiki/Masa_pemerintahan_Ali
#
# Rank: 127
# Nama Dokumen: Zakat.txt
# Similaritas Jaccard: 0.0011
# Document URL: 'https://id.wikipedia.org/wiki/Zakat
#
# Rank: 128
# Nama Dokumen: Wabah_Amwas.txt
# Similaritas Jaccard: 0.0011
# Document URL: 'https://id.wikipedia.org/wiki/Wabah_Amwas
#
# Rank: 129
# Nama Dokumen: Adam.txt
# Similaritas Jaccard: 0.0011
# Document URL: 'https://id.wikipedia.org/wiki/Adam
#
# Rank: 130
# Nama Dokumen: Al-Qur_27an.txt
# Similaritas Jaccard: 0.0010
# Document URL: 'https://id.wikipedia.org/wiki/Al-Qur%27an
#
# Rank: 131
# Nama Dokumen: Pertempuran_Badar.txt
# Similaritas Jaccard: 0.0010
# Document URL: 'https://id.wikipedia.org/wiki/Pertempuran_Badar
#
# Rank: 132
# Nama Dokumen: Neraka.txt
# Similaritas Jaccard: 0.0010
# Document URL: 'https://id.wikipedia.org/wiki/Neraka
#
# Rank: 133
# Nama Dokumen: Nabi_dan_rasul_dalam_Islam#Daftar_nabi_dan_rasul.txt
# Similaritas Jaccard: 0.0009
# Document URL: 'https://id.wikipedia.org/wiki/Nabi_dan_rasul_dalam_Islam#Daftar_nabi_dan_rasul
#
# Rank: 134
# Nama Dokumen: Umar_bin_Abdul_Aziz.txt
# Similaritas Jaccard: 0.0009
# Document URL: 'https://id.wikipedia.org/wiki/Umar_bin_Abdul_Aziz
#
# Rank: 135
# Nama Dokumen: Ibnu_Sina.txt
# Similaritas Jaccard: 0.0009
# Document URL: 'https://id.wikipedia.org/wiki/Ibnu_Sina
#
# Rank: 136
# Nama Dokumen: Abdul_Malik_bin_Marwan.txt
# Similaritas Jaccard: 0.0009
# Document URL: 'https://id.wikipedia.org/wiki/Abdul_Malik_bin_Marwan
#
# Rank: 137
# Nama Dokumen: Yusuf_dalam_Islam.txt
# Similaritas Jaccard: 0.0009
# Document URL: 'https://id.wikipedia.org/wiki/Yusuf_dalam_Islam
#
# Rank: 138
# Nama Dokumen: Utsman_bin_Affan.txt
# Similaritas Jaccard: 0.0009
# Document URL: 'https://id.wikipedia.org/wiki/Utsman_bin_Affan
#
# Rank: 139
# Nama Dokumen: Marwan_bin_al-Hakam.txt
# Similaritas Jaccard: 0.0008
# Document URL: 'https://id.wikipedia.org/wiki/Marwan_bin_al-Hakam
#
# Rank: 140
# Nama Dokumen: Yunus.txt
# Similaritas Jaccard: 0.0008
# Document URL: 'https://id.wikipedia.org/wiki/Yunus
#
# Rank: 141
# Nama Dokumen: Ibrahim.txt
# Similaritas Jaccard: 0.0008
# Document URL: 'https://id.wikipedia.org/wiki/Ibrahim
#
# Rank: 142
# Nama Dokumen: Abu_Bakar_ash-Shiddiq.txt
# Similaritas Jaccard: 0.0008
# Document URL: 'https://id.wikipedia.org/wiki/Abu_Bakar_ash-Shiddiq
#
# Rank: 143
# Nama Dokumen: Sufisme.txt
# Similaritas Jaccard: 0.0008
# Document URL: 'https://id.wikipedia.org/wiki/Sufisme
#
# Rank: 144
# Nama Dokumen: Haji.txt
# Similaritas Jaccard: 0.0007
# Document URL: 'https://id.wikipedia.org/wiki/Haji
#
# Rank: 145
# Nama Dokumen: Islam.txt
# Similaritas Jaccard: 0.0007
# Document URL: 'https://id.wikipedia.org/wiki/Islam
#
# Rank: 146
# Nama Dokumen: Khalifah#Daftar_Khalifah.txt
# Similaritas Jaccard: 0.0007
# Document URL: 'https://id.wikipedia.org/wiki/Khalifah#Daftar_Khalifah
#
# Rank: 147
# Nama Dokumen: Muhammad.txt
# Similaritas Jaccard: 0.0007
# Document URL: 'https://id.wikipedia.org/wiki/Muhammad
#
# Rank: 148
# Nama Dokumen: Umar_bin_Khattab.txt
# Similaritas Jaccard: 0.0006
# Document URL: 'https://id.wikipedia.org/wiki/Umar_bin_Khattab
#
# Rank: 149
# Nama Dokumen: Isa.txt
# Similaritas Jaccard: 0.0006
# Document URL: 'https://id.wikipedia.org/wiki/Isa
#
# Rank: 150
# Nama Dokumen: Kekhalifahan_Rasyidin.txt
# Similaritas Jaccard: 0.0006
# Document URL: 'https://id.wikipedia.org/wiki/Kekhalifahan_Rasyidin
#
# Rank: 151
# Nama Dokumen: Musa.txt
# Similaritas Jaccard: 0.0006
# Document URL: 'https://id.wikipedia.org/wiki/Musa
#
# Rank: 152
# Nama Dokumen: Muhammad_bin_Abdul_Wahhab.txt
# Similaritas Jaccard: 0.0006
# Document URL: 'https://id.wikipedia.org/wiki/Muhammad_bin_Abdul_Wahhab
#
# Rank: 153
# Nama Dokumen: Muawiyah_bin_Abu_Sufyan.txt
# Similaritas Jaccard: 0.0006
# Document URL: 'https://id.wikipedia.org/wiki/Muawiyah_bin_Abu_Sufyan
#
# Rank: 154
# Nama Dokumen: Sunni.txt
# Similaritas Jaccard: 0.0006
# Document URL: 'https://id.wikipedia.org/wiki/Sunni
#
# Rank: 155
# Nama Dokumen: Kekhalifahan_Abbasiyah#Kekhalifahan_Abbasiyah_di_Kairo.txt
# Similaritas Jaccard: 0.0005
# Document URL: 'https://id.wikipedia.org/wiki/Kekhalifahan_Abbasiyah#Kekhalifahan_Abbasiyah_di_Kairo
#
# Rank: 156
# Nama Dokumen: Khalid_bin_Walid.txt
# Similaritas Jaccard: 0.0005
# Document URL: 'https://id.wikipedia.org/wiki/Khalid_bin_Walid
#
# Waktu eksekusi: 0.008199453 detik
# Jumlah dokumen: 156
